# %% [markdown]
# # Institute of Data - Capstone Project - Customer Churn
#
# ## Table of Contents
# <ul>
#     <li><a href="#introduction">Introduction</a></li>
#     <li><a href="#data_wrangling">Data Wrangling</a></li>
#     <ul>
#         <li><a href="#data_dictionary">Data Dictionary</a></li>
#     </ul>
#     <li><a href="#exploratory">Exploratory Data Analysis</a></li>
#     <ul>
#         <li><a href="#categorical_eda">Categorical EDA</a></li>
#         <li><a href="#numerical_eda">Numerical EDA</a></li>
#         <li><a href="#customer_churn_eda">Customer Churn EDA</a></li>
#     </ul>
#     <li><a href="#modeling">Modeling</a></li>
#     <ul>
#         <li><a href="#pre-processing">Pre-Processing</a></li>
#         <li><a href="#model_selection">Model Selection</a></li>
#         <li><a href="#sampling_methods">Sampling Methods</a></li>
#         <li><a href="#cross_validation">Cross Validation</a></li>
#         <li><a href='#hyperparameter_tuning_and_model_building'>Hyperparameter Tuning and Model Building</a></li>
#         <li><a href="#feature_importance">Feature Importance</a></li>
#     </ul>
#     <li><a href="#conclusion">Conclusion</a></li>
# </ul>

# %% [markdown]
# ## Introduction <a id='introduction'></a>
#
# Customer churn is the propensity of customers to cease doing business with a company in a given time period. It is an important metric in a business sense, as it's estimated that the cost of acquiring new customers being 5-6x greater than keeping existing ones. On this point alone, it makes sense for a business to implement strategies of keeping customers and reducing their likelihood of churning.
#
# The rise of digital and ‘neo-banks’ in the Australian banking space, has resulted in a renewed focus on customer churn within banks, as customers are presented with more options as to who they bank with. Coupled with the ease of online research and applications, switching banks has never been easier for customers. It makes sense given the costs of customer churn, that banks divert resources and attention into analysing their customers behaviour and employing Machine Learning algorithms to successfully predict those that’ll churn.
#
# This notebook will address the customer churn problem facing banks, by use of the following [dataset](https://www.kaggle.com/datasets/sakshigoyal7/credit-card-customers) from Kaggle. This problem will be addressed by building a predictive model, with the aim of successfully predicting whether a customer will churn or not. A bank would then be able to use this information to appropriately implement strategies to prevent the customer from churning, where successful implementation of a predictive model and subsequent strategy would see a reduction in costs, increased revenue, and increased customer satisfaction.

# %%
## MODULES

# Core Modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Catboost
from catboost import CatBoostClassifier, Pool

# XGBoost
import xgboost as xgb

# Imblearn
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler

# SkLearn
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier, StackingClassifier, ExtraTreesClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn import metrics
from sklearn.preprocessing import OrdinalEncoder, StandardScaler

# Custom Modules
import custom_code
import helpers
from show_summary_report import show_summary, show_summary_report

# Show plots inline
# %matplotlib inline

# Pandas Options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Plot Styling
sns.set(style='darkgrid')

# %% [markdown]
# ## Data Wrangling <a id='data_wrangling'></a>

# %%
# Import Data

df = pd.read_csv('dataset/BankChurners.csv')

# Explore DataFrame

display(df.head())

# Shape
print(f'Shape: {df.shape}')

# Columns
print('\n**Columns**')
display(df.columns)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# 1              44                         6                       1
# 2              36                         4                       1
# 3              34                         3                       4
# 4              21                         5                       1
#
#    Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0                      3       12691.0                  777          11914.0
# 1                      2        8256.0                  864           7392.0
# 2                      0        3418.0                    0           3418.0
# 3                      1        3313.0                 2517            796.0
# 4                      0        4716.0                    0           4716.0
#
#    Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                 1.335             1144              42                1.625
# 1                 1.541             1291              33                3.714
# 2                 2.594             1887              20                2.333
# 3                 1.405             1171              20                2.333
# 4                 2.175              816              28                2.500
#
#    Avg_Utilization_Ratio  \
# 0                  0.061
# 1                  0.105
# 2                  0.000
# 3                  0.760
# 4                  0.000
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                           0.000093
# 1                                           0.000057
# 2                                           0.000021
# 3                                           0.000134
# 4                                           0.000022
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0                                            0.99991
# 1                                            0.99994
# 2                                            0.99998
# 3                                            0.99987
# 4                                            0.99998
# Shape: (10127, 23)
#
# **Columns**
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %% [markdown]
# Dataset contains 10,127 rows and 23 columns.
#
# The last 2 columns of this dataset should be ignored and will be dropped. I'll also drop the CLIENTNUM column as it serves no purpose in the analysis I'm going to do.

# %%
# Drop columns that aren't needed

df.drop(df.columns[[0, 21, 22]], axis=1, inplace=True)

# %%
# Rename Columns

df.columns = ['customer_churn', 'age', 'gender','num_dependents', 'education', 'marital_status', 'income', 'card_category',
             'period_of_relationship','products_held', 'months_inactive', 'num_times_contacted', 'credit_limit', 'card_balance',
             'open_to_buy_credit_avg', 'change_transaction_amount_Q4_Q1', 'transaction_amount', 'transaction_count',
             'change_transaction_count_Q4_Q1', 'card_utilisation_ratio_avg']

# %% [markdown]
# ### Data Dictionary <a id='data_dictionary'></a>
#
# - **customer_churn**: Flag to show whether the client is current or has closed accounts with the bank
# - **age**: Customer Age in years
# - **gender**: M = Male, F = Female
# - **num_dependents**: Number of dependents the customer has
# - **education**: Highest educational attainment of customer
# - **marital_status**: Marital Status (Married/Single/Divorced/Unknown)
# - **income**: Annual income category the customer falls in
# - **card_category**: Type of card held (Blue, Silver, Gold, Platinum)
# - **period_of_relationship**: Period of relationship with bank
# - **products_held**: Number of products held by customer
# - **months_inactive**: Number of inactive months in the past 12 months
# - **num_times_contacted**: Number of times contacted in the last 12 months
# - **credit_limit**: Credit limit on customers credit card
# - **card_balance**: Total revolving balance on the credit card
# - **open_to_buy_credit_avg**: Open to buy credit line (average of last 12 months)
# - **change_transaction_amount_Q4_Q1**: Change in transaction amount (Q4 over Q1)
# - **transaction_amount**: Total transaction amount (last 12 months)
# - **transaction_count**: Number of transactions (last 12 months)
# - **change_transaction_count_Q4_Q1**: Change in transaction count (Q4 over Q1)
# - **card_utilisation_ratio_avg**: Average card utilisation ratio

# %% [markdown]
# There is a good amount of information related to the customers in this dataset, that may have an impact as to whether the customer will churn from the bank. The target variable for this analysis is *customer_churn*, where I'll be coding 1 to represent a customer that has churned, and 0 to represent the converse.

# %%
# Info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   customer_churn                   10127 non-null  object
#  1   age                              10127 non-null  int64
#  2   gender                           10127 non-null  object
#  3   num_dependents                   10127 non-null  int64
#  4   education                        10127 non-null  object
#  5   marital_status                   10127 non-null  object
#  6   income                           10127 non-null  object
#  7   card_category                    10127 non-null  object
#  8   period_of_relationship           10127 non-null  int64
#  9   products_held                    10127 non-null  int64
#  10  months_inactive                  10127 non-null  int64
#  11  num_times_contacted              10127 non-null  int64
#  12  credit_limit                     10127 non-null  float64
#  13  card_balance                     10127 non-null  int64
#  14  open_to_buy_credit_avg           10127 non-null  float64
#  15  change_transaction_amount_Q4_Q1  10127 non-null  float64
#  16  transaction_amount               10127 non-null  int64
#  17  transaction_count                10127 non-null  int64
#  18  change_transaction_count_Q4_Q1   10127 non-null  float64
#  19  card_utilisation_ratio_avg       10127 non-null  float64
# dtypes: float64(5), int64(9), object(6)
# memory usage: 1.5+ MB

# %% [markdown]
# There aren't any null values in this dataset, though I'll need to check if there are any values that appear incorrect. For example, a value of 0 in Age would be an incorrect value.
#
# In terms of data types, all variables are correctly classified.

# %%
# Describe

df.describe().T
# Out:
#                                    count         mean          std     min  \
# age                              10127.0    46.325960     8.016814    26.0
# num_dependents                   10127.0     2.346203     1.298908     0.0
# period_of_relationship           10127.0    35.928409     7.986416    13.0
# products_held                    10127.0     3.812580     1.554408     1.0
# months_inactive                  10127.0     2.341167     1.010622     0.0
# num_times_contacted              10127.0     2.455317     1.106225     0.0
# credit_limit                     10127.0  8631.953698  9088.776650  1438.3
# card_balance                     10127.0  1162.814061   814.987335     0.0
# open_to_buy_credit_avg           10127.0  7469.139637  9090.685324     3.0
# change_transaction_amount_Q4_Q1  10127.0     0.759941     0.219207     0.0
# transaction_amount               10127.0  4404.086304  3397.129254   510.0
# transaction_count                10127.0    64.858695    23.472570    10.0
# change_transaction_count_Q4_Q1   10127.0     0.712222     0.238086     0.0
# card_utilisation_ratio_avg       10127.0     0.274894     0.275691     0.0
#
#                                       25%       50%        75%        max
# age                                41.000    46.000     52.000     73.000
# num_dependents                      1.000     2.000      3.000      5.000
# period_of_relationship             31.000    36.000     40.000     56.000
# products_held                       3.000     4.000      5.000      6.000
# months_inactive                     2.000     2.000      3.000      6.000
# num_times_contacted                 2.000     2.000      3.000      6.000
# credit_limit                     2555.000  4549.000  11067.500  34516.000
# card_balance                      359.000  1276.000   1784.000   2517.000
# open_to_buy_credit_avg           1324.500  3474.000   9859.000  34516.000
# change_transaction_amount_Q4_Q1     0.631     0.736      0.859      3.397
# transaction_amount               2155.500  3899.000   4741.000  18484.000
# transaction_count                  45.000    67.000     81.000    139.000
# change_transaction_count_Q4_Q1      0.582     0.702      0.818      3.714
# card_utilisation_ratio_avg          0.023     0.176      0.503      0.999

# %% [markdown]
# Reviewing the above table, it appears as though there aren't any unexpected values in each numeric column. The min and max values of each column seem reasonable.
#
# Unfortunately, there is limited information on exactly what some of the columns mean. For example, the 'Avg_Open_To_Buy' column is quite ambiguous in its definition provided upon sourcing the dataset.
#
# I can dig into the data a little further, by exploring some of the following questions:
#
# - What is the relationship between Transaction Amount and Transaction Count, and how does this differ between current and churned customers?
# - Do customers with more products, spend more?
#
# This information may be useful in better understanding our customers spending habits, to assist in developing a marketing strategy to reduce customer churn.

# %%
# Summarise

helpers.summarise(df).sort_values(by='n_unique', ascending=False)
# Out:
#                                  n_missing  p_missing  n_unique    dtype
# open_to_buy_credit_avg                   0        0.0      6813  float64
# credit_limit                             0        0.0      6205  float64
# transaction_amount                       0        0.0      5033    int64
# card_balance                             0        0.0      1974    int64
# change_transaction_amount_Q4_Q1          0        0.0      1158  float64
# card_utilisation_ratio_avg               0        0.0       964  float64
# change_transaction_count_Q4_Q1           0        0.0       830  float64
# transaction_count                        0        0.0       126    int64
# age                                      0        0.0        45    int64
# period_of_relationship                   0        0.0        44    int64
# education                                0        0.0         7   object
# months_inactive                          0        0.0         7    int64
# num_times_contacted                      0        0.0         7    int64
# products_held                            0        0.0         6    int64
# income                                   0        0.0         6   object
# num_dependents                           0        0.0         6    int64
# card_category                            0        0.0         4   object
# marital_status                           0        0.0         4   object
# gender                                   0        0.0         2   object
# customer_churn                           0        0.0         2   object

# %% [markdown]
# The above confirms again no null values, as well as shows that all the categorical variables will be useful as they have a low number of categories - Education Level is the highest with 7.
#
# Note that the *helpers.summarise* is a function from custom code.

# %%
# Check Categorical Columns

round(df.describe(exclude = ['float', 'int64']),2)
# Out:
#            customer_churn gender education marital_status          income  \
# count               10127  10127     10127          10127           10127
# unique                  2      2         7              4               6
# top     Existing Customer      F  Graduate        Married  Less than $40K
# freq                 8500   5358      3128           4687            3561
#
#        card_category
# count          10127
# unique             4
# top             Blue
# freq            9436

# %% [markdown]
# The above table tells me that a typical customer is current, female, graduate, married, earns less than $40k and has a Blue credit card.

# %%
# Convert Attrition_Flag to 0 = Current Customer & 1 = Churned Customer

df.customer_churn = df.customer_churn.replace('Existing Customer', 0)
df.customer_churn = df.customer_churn.replace('Attrited Customer', 1)

# %% [markdown]
# The above was done to convert the target variable column to 0 and 1 values. This is required for machine learning models. 0 represents current customer and 1 represents churned customer.

# %% [markdown]
# Below I'll extract out the numeric and categorical column names, as this will be useful for further analysis.

# %%
# List of columns with unique values <= 7

discrete_cols = [col for col in df.columns if df[col].nunique() <= 7]
discrete_cols.remove('customer_churn')

# List of all other columns
contin_cols = [col for col in df.columns if col not in discrete_cols]
contin_cols.remove('customer_churn')

# %% [markdown]
# To understand if I need to do any data wrangling on the categorical columns, I first need to see what values make up these variables. I'll loop through the categorical columns and display value counts.

# %%
# Loop through categorical columns and display value counts

for col in discrete_cols:
    display(df[col].value_counts())
    print('-'*35)
# Out:
# F    5358
# M    4769
# Name: gender, dtype: int64
# -----------------------------------
# 3    2732
# 2    2655
# 1    1838
# 4    1574
# 0     904
# 5     424
# Name: num_dependents, dtype: int64
# -----------------------------------
# Graduate         3128
# High School      2013
# Unknown          1519
# Uneducated       1487
# College          1013
# Post-Graduate     516
# Doctorate         451
# Name: education, dtype: int64
# -----------------------------------
# Married     4687
# Single      3943
# Unknown      749
# Divorced     748
# Name: marital_status, dtype: int64
# -----------------------------------
# Less than $40K    3561
# $40K - $60K       1790
# $80K - $120K      1535
# $60K - $80K       1402
# Unknown           1112
# $120K +            727
# Name: income, dtype: int64
# -----------------------------------
# Blue        9436
# Silver       555
# Gold         116
# Platinum      20
# Name: card_category, dtype: int64
# -----------------------------------
# 3    2305
# 4    1912
# 5    1891
# 6    1866
# 2    1243
# 1     910
# Name: products_held, dtype: int64
# -----------------------------------
# 3    3846
# 2    3282
# 1    2233
# 4     435
# 5     178
# 6     124
# 0      29
# Name: months_inactive, dtype: int64
# -----------------------------------
# 3    3380
# 2    3227
# 1    1499
# 4    1392
# 0     399
# 5     176
# 6      54
# Name: num_times_contacted, dtype: int64
# -----------------------------------

# %% [markdown]
# There are many 'Unknown' values in 3/5 of the categorical columns. I'll leave these as is for now and first see what sort of performance I get with the models. This may be an area to explore for future improvement, I could look at Imputing the 'Unknown' values.

# %% [markdown]
# ## Exploratory Data Analysis <a id='exploratory'></a>

# %% [markdown]
# The target variable in this analysis is the 'customer_churn' column, which tells me which customers are current and which ones have churned. I'll begin by understanding the split between these two values and will achieve this using a bar plot.
#
# #### Target Variable - Churned Customers

# %%
# Create Figure & Axes

fig, ax = plt.subplots(figsize=(10,8))

# Draw Countplot

sns.countplot(data=df, x='customer_churn', ax=ax)

# Formatting

ax.set_title('Number of Churned Customers', fontsize=16, fontweight='bold')
ax.set_xlabel('')
ax.set_ylabel('')
ax.set_xticklabels(['Current Customer', 'Churned Customer'])
sns.despine(fig=fig, bottom=True)

# Show Plot

plt.tight_layout()
plt.show()

# Table

helpers.find_frequency(df.customer_churn)
# Out:
#    p_frequency  n_frequency
# 0      0.83934         8500
# 1      0.16066         1627

# %% [markdown]
# The data I'm working with has a much larger number of current customers, relative to number of customers that have churned (84% vs 16%). The imbalance may impact the performance of the baseline models. If that is the case, it can be addressed using Under or Over Sampling techniques.
#
# Let's now get an overview of all the feature variables.

# %% [markdown]
# ### Categorical EDA <a id='categorical_eda'></a>

# %%
# Instantiate figure

plt.figure(figsize=(15, 20))
plt.subplots_adjust(hspace=0.5)

# Loop through the length of columns and keep track of index

for n, col in enumerate(discrete_cols):
    # Add a new subplot iteratively
    ax = plt.subplot(7,2, n+1)
    
    # Plot histogram on new subplot
    sns.countplot(data=df, x=col, ax=ax,
                 order = df[col].value_counts().index)
    
    # chart formatting
    ax.set_title(col.upper())
    ax.set_xlabel("")
    ax.set_ylabel("")

    plt.tight_layout()

# %% [markdown]
# **Key Observations:**
# - Close to even split of Male and Female Customers
# - Most customers have at least one dependent
# - Multiple education levels, with Graduate being the most common
# - Most customers are Married or Single
# - Most customers earn less than \$40k
# - Most customers are on the 'Blue' Card
# - 3 Products is the most common holding for customers
# - 3 months is the most common number of months for a customer to be inactive. Small number in >4 months.
# - The bank tends to not contact customers more than 4 times in a 12-month period
#
# I will need to encode these variables prior to training any machine learning models. One-Hot Encoding can be used on Gender & Martial Status and Ordinal Encoding on Education, Income and Card Category.

# %%
## Plots for Slides
relevant_cols = ['gender', 'education', 'marital_status', 'income']

# Instantiate figure

plt.figure(figsize=(15, 20))
plt.subplots_adjust(hspace=0.5)

# Loop through the length of columns and keep track of index

for n, col in enumerate(relevant_cols):
    # Add a new subplot iteratively
    ax = plt.subplot(7,2, n+1)
    
    # Plot histogram on new subplot
    sns.countplot(data=df, x=col, ax=ax,
                 order = df[col].value_counts().index)
    
    # chart formatting
    ax.set_title(col.upper())
    ax.set_xlabel("")
    ax.set_ylabel("")

    plt.tight_layout()

# %% [markdown]
# ### Numerical EDA <a id='numerical_eda'></a>
#
# There are 15 numerical columns, which I'll initially explore using a combination of histograms and boxplots. This'll provide some insight as to their distribution shape, as well as any potential outliers.
#
# ###### Histograms

# %%
# Instantiate figure

plt.figure(figsize=(15, 20))
plt.subplots_adjust(hspace=0.5)

# Loop through the length of columns and keep track of index

for n, col in enumerate(contin_cols):
    # Add a new subplot iteratively
    ax = plt.subplot(7,4, n+1)
    
    # Plot histogram on new subplot
    sns.histplot(data=df, x=col, ax=ax)
    
    # chart formatting
    ax.set_title(col.upper())
    ax.set_xlabel("")
    ax.set_ylabel("")

    plt.tight_layout()

# %% [markdown]
# **Key Observations:**
# - Age is the most normally distributed out of all the numeric variables
# - Period of relationship shows that there is a substantial number of customers in this dataset that have been with the bank for 36 months. This may be due to a marketing push done by the bank around that time to acquire new customers.
# - Credit Limit & Open to buy credit have a very similar distribution. With what seems to be many outliers at their tails.
# - Lots of customers appear to have a low balance on their credit card, then the distribution is normal, with a spike at the tail. This spike may be the customers with a higher credit limit.
# - Change in transaction amount and count shows that most customers in this dataset transacted less in both amount and count, over the Q4 to Q1 period.
# - Total transaction amount displays a multi modal distribution, with 4 apparent peaks. This would be a good variable to explore further, to better understand customers spending habits. The transaction count distribution only has 2 peaks.

# %% [markdown]
# ###### Boxplots

# %%
### Instantiate figure

plt.figure(figsize=(15, 20))
plt.subplots_adjust(hspace=0.5)

# Loop through the length of columns and keep track of index

for n, col in enumerate(contin_cols):
    # Add a new subplot iteratively
    ax = plt.subplot(7,3, n+1)
    
    # Plot histogram on new subplot
    sns.boxplot(data=df, x=col, ax=ax)
    
    # chart formatting
    ax.set_title(col.upper())
    ax.set_xlabel("")

    plt.tight_layout()

# %% [markdown]
# Boxplots are useful to visually observe the outliers present in a distribution. I can see from the above plots that some of the variables in this dataset contain many outliers. These outliers are mainly present in variables that describe a customer’s spending habits.
#
# Income and Spending habits tend to be highly skewed distributions, given the disparity and inequality in incomes amongst individuals. Given that, we'd expect to see outliers of this nature.

# %% [markdown]
# ### Customer Churn EDA <a id='customer_churn_eda'></a>
#
# The above graphs have given a sense of the distribution of each individual variable on its own. I'll now move to exploring how these variables relate to the target variable of whether a customer has churned or not.
#
# For the discrete variables, I'll look at the countplot and barplot side by side, showing the mean value of the target variable in the bar plot. This'll give a sense of whether the variable impacts the customer churn.

# %%
for col in discrete_cols:
    helpers.plot_discrete(df, col, 'customer_churn')

# %% [markdown]
# **Key Observations:**
# - Customers with Doctorates appear the most likely to churn
# - Customers with 3 or more dependents are the least likely to churn
# - Customers inactive for 4 months are most likely to churn. Seems as though all customers have been inactive for at least 1 month.
# - Most customers that were contacted 6 times churned and the more times a customer was contacted, the higher chance of churning is present.
#
# This insight that contacting customers more may have an impact on their likelihood to churn is important, as it may assist in developing a strategy to prevent churn.

# %%
# Subset customers contacted 5 or 6 times
df_subset = df[(df.num_times_contacted == 6) | (df.num_times_contacted == 5)]

# Value counts of target variable
df_subset.customer_churn.value_counts(normalize=True)
# Out:
# 0    0.508696
# 1    0.491304
# Name: customer_churn, dtype: float64

# %% [markdown]
# Looking at only customers that have been contacted 5 or 6 times in the past month, the split of current and churned customers rises to roughly 50/50. It appears that some customers may get fed up with the excessive contact and be part of the reason for them leaving.

# %%
# Create Figure & Axes

fig, ax = plt.subplots(figsize=(10,8))

# Draw Countplot

sns.countplot(data=df, x='num_times_contacted', hue='customer_churn', ax=ax)

# Formatting

ax.set_title('Excessive Client Contact May Influence Customer Churn', fontsize=16, fontweight='bold')
ax.set_xlabel('Number of Times Contacted')
ax.set_ylabel('Customer Count')
sns.despine(fig=fig, bottom=True)

handles, labels  =  ax.get_legend_handles_labels()
ax.legend(handles, ['Current Customer', 'Churned Customer'], loc='upper right')

# Show Plot

plt.tight_layout()
plt.show()

# %% [markdown]
# The above barplot shows this insight even further, the relative difference between current and churned customers for each contact numbers gets smaller as the number of times contacted increases.
#
# ---

# %% [markdown]
# For the continuous variables, I'll look at the kdeplot and boxplot side by side, with the target variable separated out by colour. This will also allow me to see any relationship between customer churn and the respective variable.

# %%
for col in contin_cols:
    helpers.plot_continuous(df, col, 'customer_churn')

# %% [markdown]
# **Key Observations:**
# - Customers with lower revolving balances are more likely to churn.
# - Customers with lower transaction balances are more likely to churn. Though for customers with a balance of 7500-10000, churn is more likely to happen here.
# - Customers with lower transaction counts are more likely to churn.
# - Customers with lower utilisation are more likely to churn.
#
# I'll now explore some of the earlier questions I raised, to see if I can pull out any further interesting insights.

# %%
## Create Cleaner Plot for presentation

# Create Figure & Axes

fig, ax = plt.subplots(figsize=(12,8))

# Draw Countplot

sns.kdeplot(data=df, x='transaction_amount', hue ='customer_churn', ax=ax, shade=True, common_norm = False)

# Formatting

ax.set_title('Distribution of Customers Transaction Amount by Churn', fontsize=16, fontweight='bold')
ax.set_xlabel('transaction amount', fontsize=14)
ax.set_ylabel('density', fontsize=14)
sns.despine(fig=fig, bottom=True)

ax.legend(title='', labels=['Churned Customer', 'Current Customer'])

# Show Plot

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### What is the relationship between Transaction Amount and Transaction Count, and how does this differ between current and churned customers?

# %%
# Create Figure & Axes

fig, ax = plt.subplots(figsize=(12,8))

# Draw Countplot

sns.scatterplot(data=df, x='transaction_amount', y='transaction_count' ,hue ='customer_churn', ax=ax)

# Formatting

ax.set_xlabel('Transaction Amount', fontsize=14)
ax.set_ylabel('Transaction Count', fontsize=14)
ax.set_title('Transaction Amount & Count - Does it differ between current and churned customers?',
            fontsize=16, fontweight='bold')
sns.despine(fig=fig, bottom=True)

handles, labels  =  ax.get_legend_handles_labels()
ax.legend(handles, ['Current Customer', 'Churned Customer'], loc='lower right')

# Show Plot

plt.tight_layout()
plt.show()

# %% [markdown]
# **Key Observations**
# - There is a clear distinction between the transaction activity for current customers and churned customers.
# - Churned customers on average appear to spend less and have less transactions than the current customers.
# - No customer has left the bank if they spend more than $12,000 roughly

# %% [markdown]
# #####  Do customers with more products, spend more? How does this look between current and churned customers?

# %%
# Create Figure & Axes

fig, ax = plt.subplots(figsize=(12,8))

# Draw Countplot

sns.stripplot(data=df, x='products_held', y='transaction_amount' , jitter=0.4, hue ='customer_churn', ax=ax)

# Formatting

ax.set_xlabel('Number of Products Held', fontsize=14)
ax.set_ylabel('Transaction Amount', fontsize=14)
ax.set_title('Do customers with more products spend more?', fontsize=16, fontweight='bold')
sns.despine(fig=fig, bottom=True)

handles, labels  =  ax.get_legend_handles_labels()
ax.legend(handles, ['Current Customer', 'Churned Customer'], loc='upper right')

# Show Plot

plt.tight_layout()
plt.show()

# %% [markdown]
# **Key Observations**
# - Customers with 1 or 2 products, that spend less than roughly $3,000 are likely to churn. Looking at the graph, very few current customers show this activity.
# - Customers with more products appear to spend less than those with less products.

# %% [markdown]
# Next, I'll plot the Correlation Matrix, to get a sense of which variables appear to influence Customer Churn the most.

# %% [markdown]
# #### Correlation Matrix

# %%
# Set Theme

sns.set_theme(style="white")

# Calculate correlations

corr = df.corr()

# Mask for top triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(18, 18))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5},
           annot=np.round(corr.values,2))

plt.show()

# %%
sns.set_theme(style="darkgrid")

# %% [markdown]
# The above shows me that transaction_count, change_transaction_count_Q4_Q1 and card_balance have the strongest negative correlation with the target variable. Which indicates that customer activity may be the best predictor of whether they will churn or not, and it looks to have less bearing on features such as age, period of relationship with bank and credit limit.

# %% [markdown]
# Some key themes that can be taken out from this EDA, is that customers that show less activity using their products, are more likely to churn. This may be due to the client’s intention of winding up and is intentionally moving money and activity to another bank. Additionally, customers with a higher number of dependents are more likely to stay. This may be because a customer doesn't have the time to search for other options.
#
# Regardless of the reasons, it would be beneficial for this bank to set up systems of identifying these trends and applying some intervention to re-engage the customer. Though it should be noted that too much contact may be counterproductive.

# %% [markdown]
# ## Modeling <a id='modeling'></a>
#
# ### Pre-Processing <a id='pre-processing'></a>
#
# ##### Encoding

# %% [markdown]
# I'll apply Ordinal Encoding on education, card category and income. Placing the 'Unknown' variable as the lowest value, to signify least importance, and subsequently have the lowest impact on model training.

# %%
# Educational Level - Set Categories

ordinal = OrdinalEncoder(categories=[['Unknown', 'Uneducated', 'High School', 
                                      'College', 'Graduate', 'Post-Graduate',
                                     'Doctorate']])

# Fit on Dataframe

df['education'] = ordinal.fit_transform(df[['education']])

# %%
# Card Category - Set Categories

ordinal = OrdinalEncoder(categories=[['Blue', 'Silver', 'Gold', 'Platinum']])

# Fit on Dataframe

df['card_category'] = ordinal.fit_transform(df[['card_category']])

# %%
# Income Category - Set Categories

ordinal = OrdinalEncoder(categories=[['Unknown', 'Less than $40K', '$40K - $60K',
                                     '$60K - $80K', '$80K - $120K', '$120K +']])

# Fit on Dataframe

df['income'] = ordinal.fit_transform(df[['income']])

# %% [markdown]
# As gender is binary, I'll pre-process that column without the use of a package.

# %%
df['gender'] = df['gender'].apply(lambda x: 1 if x == 'M' else 0)

# %% [markdown]
# I'll apply One Hot Encoding on Marital Status. To do this, we'll use pandas get_dummies().

# %%
# Get Dummies

df = pd.get_dummies(df)

# %% [markdown]
# ###### Features and Target Variables
#
# Creating the Feature and Target Variables

# %%
# Create X & Y

y = df.customer_churn
X = df.drop('customer_churn', axis=1)

# %% [markdown]
# ##### Train Test Split
#
# The data will be split up, one split, known as the train set will be to train the model. The other set is the test set, which will be used to test the model.
#
# I'll split 70/30, with the use of stratify, which ensures an even split of target variable outcomes between the two splits.

# %%
# Train Test Split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,
                                                   random_state=0, stratify=y)

# %% [markdown]
# ###### Standardise
#
# I'll standardise our data when training each model, by use of Pipeline() and StandardScaler().

# %% [markdown]
# ### Model Selection <a id='model_selection'></a>
#
# The business problem is to successfully predict if a customer will churn. I need to consider what our model should focus on in terms of a performance metric.
#
# When the model predicts that a customer will churn, they should then be targeted with the appropriate strategy to reduce their chance of churning.
#
# Let's consider the *cost* of when the model predicts a False Positive and False Negative.
#
# **False Positive**
#
# The model would classify this customer to churn, the business would then target the customer with the strategy to prevent churn. Though if this client wasn't going to churn, the targeted strategy will most likely have little impact.
#
# **False Negative**
#
# The model wouldn't classify this customer to churn, the business would do nothing, the customer may proceed to churn. The business has now lost a customer, without any intervention.
#
# The cost of applying an approved strategy to a customer would be much smaller than the cost of losing the customer. Based on this, we should be looking to build a model that minimises the False Negatives. The performance metric for this is **Recall**.
#
# Though looking at the Recall score in isolation wouldn't be advised, as we still don't want a model that predicts many False Positives. As a result, we'll make use of the **F1** as the primary scoring metric. We can then seek to optimise the model for higher Recall, depending on the businesses’ appetite.

# %% [markdown]
# ###### Baseline Models
#
# The below cell contains all the models we'll train for our initial benchmark and comparison.

# %%
# Base Learners - Stacking

base_learners = [
                 ('XGBoost', xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss')),
                 ('AdaBoost', AdaBoostClassifier()),
                 ('Random Forest', RandomForestClassifier(random_state=0))
                ]

# List of baseline models

models = [
    ('Logistic Regression', LogisticRegression()),
    ('Decision Tree', DecisionTreeClassifier(random_state=0)),
    ('Random Forest', RandomForestClassifier(random_state=0)),
    ('Support Vector Machine', SVC(probability=True)),
    ('K-Nearest Neighbors', KNeighborsClassifier()),
    ('GaussianNB', GaussianNB()),
    ('AdaBoost', AdaBoostClassifier()),
    ('XGBoost', xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss')),
    ('CatBoost', CatBoostClassifier(random_seed=0, verbose=False)),
    ('ExtraTree', ExtraTreesClassifier()),
    ('Stacking', StackingClassifier(estimators=base_learners, 
                                    final_estimator=CatBoostClassifier(random_seed=0, verbose=False)))
    
]

# %% [markdown]
# I've created a function below that will be used to test each model against each other, while using different sampling methods. As we have an imbalanced dataset, it will be useful to test different sampling methods to see if there is an increase in performance.

# %%
# Create Function for model comparison

def model_comparision(models, sampler=''):
    
    # Dictionary to hold scores
    models_scores = {}
    
    # Loop through each model
    for model in models:
        
        # Steps for pipeline - Include sampler if passed into function
        if sampler:
            steps = [('scaler', StandardScaler()), ('sampler', sampler), model]
        else:
            steps = [('scaler', StandardScaler()), model]
            
        # Create Pipeline
        pipeline = Pipeline(steps)

        # Train model
        model_trained = pipeline.fit(X_train, y_train)

        # Predictions
        y_pred = model_trained.predict(X_test)
        y_prob = model_trained.predict_proba(X_test)

        # Store model and test recall in dictionary
        models_scores[model[0]] = [np.round(metrics.f1_score(y_test, y_pred), 4),
                                   np.round(metrics.recall_score(y_test, y_pred), 4),
                                   np.round(metrics.precision_score(y_test, y_pred), 4),
                                   np.round(metrics.roc_auc_score(y_test, y_prob[:,1]), 4),
                                   np.round(metrics.accuracy_score(y_test, y_pred), 4),                                
                                   ]
        
    # Convert dictionary to dataframe

    model_scores_df = pd.DataFrame.from_dict(models_scores, orient='index', 
                                             columns=['F1', 'Recall', 'Precision', 'AUC', 'Accuracy'])

    # Sort Values

    model_scores_df = model_scores_df.sort_values(by='F1', ascending=False)
    
    # Plot Values
    fig, axes = plt.subplots(figsize=(5,5))

    sns.barplot(data=model_scores_df, 
                y=model_scores_df.index, 
                x='F1', 
                palette='BuPu_r', 
                ax=axes)
    
    
    
    return(model_scores_df)

# %%
# Baseline

print('*'*10 + ' Baseline Model Comparision ' + '*'*10)
model_comparision(models)
# Out:
# ********** Baseline Model Comparision **********
#                             F1  Recall  Precision     AUC  Accuracy
# CatBoost                0.9134  0.8750     0.9553  0.9944    0.9733
# XGBoost                 0.8996  0.8627     0.9397  0.9923    0.9691
# Stacking                0.8924  0.8586     0.9290  0.9915    0.9668
# AdaBoost                0.8584  0.8135     0.9085  0.9833    0.9569
# Random Forest           0.8565  0.7828     0.9455  0.9881    0.9579
# Decision Tree           0.7924  0.7664     0.8202  0.8671    0.9355
# ExtraTree               0.7634  0.6414     0.9428  0.9823    0.9362
# Support Vector Machine  0.7494  0.6496     0.8855  0.9570    0.9302
# Logistic Regression     0.6722  0.5840     0.7917  0.9163    0.9085
# GaussianNB              0.6535  0.6086     0.7055  0.8703    0.8963
# K-Nearest Neighbors     0.6164  0.4857     0.8434  0.8810    0.9029

# %% [markdown]
# CatBoost and XGBoost out of the box have scored very well on our test data, followed closely by the Stacking Ensemble I put together. Random Forest and AdaBoost have decent scores, though they perform much more poorly on Recall compared to the first three.
#
# Next, I'll apply some sampling methods to see if an improvement in baseline scores can be found.

# %% [markdown]
# ### Sampling Methods <a id='sampling_methods'></a>
#
# For this analysis, I'll test out 3 different sampling methods. All these methods are from the Imblearn packages.
#
# - RandomOverSampler
# - RandomUnderSampler
# - SMOTE

# %%
# Create Sampler Objects

ros = RandomOverSampler(random_state=0)
rus = RandomUnderSampler(random_state=0)
smote = SMOTE(random_state=0)

# %%
# RandomOverSampler

print('*'*10 + ' RandomOverSampler Model Comparision ' + '*'*10)
model_comparision(models, ros)
# Out:
# ********** RandomOverSampler Model Comparision **********
#                             F1  Recall  Precision     AUC  Accuracy
# CatBoost                0.9207  0.9160     0.9255  0.9945    0.9747
# XGBoost                 0.9121  0.9037     0.9207  0.9938    0.9720
# Random Forest           0.8730  0.8381     0.9109  0.9896    0.9608
# AdaBoost                0.8294  0.9016     0.7679  0.9819    0.9404
# Support Vector Machine  0.7883  0.8545     0.7316  0.9610    0.9263
# Decision Tree           0.7809  0.7520     0.8119  0.8594    0.9322
# ExtraTree               0.7453  0.6148     0.9464  0.9810    0.9325
# Stacking                0.7317  0.5840     0.9794  0.9905    0.9312
# K-Nearest Neighbors     0.6377  0.7828     0.5380  0.8740    0.8572
# Logistic Regression     0.6318  0.8176     0.5148  0.9180    0.8470
# GaussianNB              0.5673  0.7951     0.4409  0.8705    0.8052

# %%
# RandomUnderSampler

print('*'*10 + ' RandomUnderSampler Model Comparision ' + '*'*10)
model_comparision(models, rus)
# Out:
# ********** RandomUnderSampler Model Comparision **********
#                             F1  Recall  Precision     AUC  Accuracy
# CatBoost                0.8840  0.9529     0.8245  0.9924    0.9599
# XGBoost                 0.8641  0.9447     0.7962  0.9904    0.9523
# Random Forest           0.8537  0.9508     0.7746  0.9871    0.9477
# Stacking                0.8481  0.9324     0.7778  0.9885    0.9464
# AdaBoost                0.8292  0.9201     0.7546  0.9829    0.9391
# ExtraTree               0.8058  0.9139     0.7205  0.9763    0.9293
# Support Vector Machine  0.7394  0.8607     0.6481  0.9519    0.9026
# Decision Tree           0.7329  0.8996     0.6183  0.8967    0.8947
# Logistic Regression     0.6370  0.8074     0.5260  0.9162    0.8523
# K-Nearest Neighbors     0.6287  0.8361     0.5037  0.8992    0.8414
# GaussianNB              0.5432  0.7664     0.4207  0.8539    0.7930

# %%
# SMOTE

print('*'*10 + ' SMOTE Model Comparision ' + '*'*10)
model_comparision(models, smote)
# Out:
# ********** SMOTE Model Comparision **********
#                             F1  Recall  Precision     AUC  Accuracy
# CatBoost                0.9143  0.8852     0.9453  0.9935    0.9733
# XGBoost                 0.9018  0.8750     0.9303  0.9928    0.9694
# Random Forest           0.8686  0.8463     0.8920  0.9863    0.9589
# Stacking                0.8685  0.8525     0.8851  0.9883    0.9585
# AdaBoost                0.8415  0.8811     0.8052  0.9757    0.9467
# ExtraTree               0.8214  0.7541     0.9020  0.9781    0.9474
# Support Vector Machine  0.7839  0.8176     0.7528  0.9589    0.9276
# Decision Tree           0.7824  0.8033     0.7626  0.8777    0.9283
# Logistic Regression     0.6459  0.8074     0.5383  0.9171    0.8578
# K-Nearest Neighbors     0.6332  0.8135     0.5183  0.8961    0.8486
# GaussianNB              0.5656  0.7418     0.4571  0.8555    0.8170

# %% [markdown]
# RandomOverSampling provided the largest impact on our baseline models. Looking at CatBoost, it's improved the test F1 score to 0.92, and recall to 0.92.
#
# Prior to picking which model to use, I'll use cross validation on the top 4 performers after applying Random Over Sampling.

# %% [markdown]
# ### Cross Validation <a id='cross_validation'></a>
#
# Applying cross validation to the top 4 models above (CatBoost, XGBoost, Random Forest, AdaBoost)

# %%
# Create Dictionary to store models

models = {
        'CatBoost': CatBoostClassifier(random_seed=0, verbose=False),
        'XGBoost': xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
        'Random Forest': RandomForestClassifier(random_state=0),
        'AdaBoost': AdaBoostClassifier()

}

# Loop through each model, printing average recall score for 5 fold cross validation

for model in models:
    
    # Create Pipeline
    
    pipeline = Pipeline([('transformer', StandardScaler()), ('sampler', ros), ('estimator', models[model])])
    
    # Cross Validation - 5 Folds
    
    print(f'{model} - 5 Fold CV - Average F1')
    print(np.mean(cross_val_score(pipeline, X_train, y_train, cv=5, scoring='f1')))
    print('*'*50)
# Out:
# CatBoost - 5 Fold CV - Average F1
# 0.913406095316809
# **************************************************
# XGBoost - 5 Fold CV - Average F1
# 0.9002479493195565
# **************************************************
# Random Forest - 5 Fold CV - Average F1
# 0.8622837302443866
# **************************************************
# AdaBoost - 5 Fold CV - Average F1
# 0.8260982157108382
# **************************************************

# %% [markdown]
# Cross Validation confirms that the initial baseline scores weren't due to random chance on how the data was initially split. This gives me the confidence to make the decision to use CatBoost as the final model.

# %% [markdown]
# ### Hyperparameter Tuning & Model Building <a id='hyperparameter_tuning_and_model_building'></a>
#
# Based on the above work, I'll be using CatBoost as the model to predict whether a customer will churn. This next section will be building it out entirely, including further fine tuning to improve the F1 and Recall score.
#
# I was able to find the optimal parameters using Optuna, which I ran in a separate notebook using Colab, as I kept running into an error in this notebook that I couldn’t solve. The below code is just highlighting how GridSearchCV can be used to find optimal parameters.

# %%
# Model

cb = CatBoostClassifier(random_seed=0, verbose=500)

# Pipeline

pipe = Pipeline(steps=[("scaler", StandardScaler()), ('ros', ros), ("cat", cb)])

# Parameters to search over

# param_grid = {
#     "cat__depth": [9, 10],
#     "cat__learning_rate": [0.04769487291726708, 0.06769487291726708],
#     "cat__l2_leaf_reg": [8.57433418306558, 8.57433418306558],
#     "cat__boosting_type": ['Ordered']
# }

# param_grid = {
#     "cat__depth": [6, 7],
#     "cat__learning_rate": [0.03],
#     "cat__l2_leaf_reg": [3, 4],
#     "cat__iterations": [500, 1000],
#     "cat__grow_policy": ['SymmetricTree', 'Depthwise', 'Lossguide']
# }

param_grid = {
    "cat__depth": [6, 7, 8, 9,  10],
    "cat__learning_rate": [0.03, 0.06],
    "cat__l2_leaf_reg": [3, 5, 7, 9],
    "cat__grow_policy": ['SymmetricTree', 'Lossguide'],
    "cat__boosting_type": ['Ordered', 'Plain']
}


# Search

search = GridSearchCV(pipe, param_grid, cv=3)

# Fit

search.fit(X_train, y_train)

# Ouput

print(search.best_params_)
# Out:
# 0:	learn: 0.6558433	total: 18.3ms	remaining: 18.3s
# 500:	learn: 0.0429678	total: 4.57s	remaining: 4.55s
# 999:	learn: 0.0296152	total: 8.93s	remaining: 0us
# 0:	learn: 0.6613620	total: 9.91ms	remaining: 9.9s
# 500:	learn: 0.0468638	total: 4.56s	remaining: 4.54s
# 999:	learn: 0.0283842	total: 8.96s	remaining: 0us
# 0:	learn: 0.6498174	total: 35ms	remaining: 35s
# 500:	learn: 0.0402317	total: 4.61s	remaining: 4.59s
# 999:	learn: 0.0236162	total: 8.94s	remaining: 0us
# 0:	learn: 0.6209797	total: 21.2ms	remaining: 21.2s
# 500:	learn: 0.0318895	total: 4.45s	remaining: 4.44s
# 999:	learn: 0.0262981	total: 8.31s	remaining: 0us
# 0:	learn: 0.6316818	total: 19.1ms	remaining: 19.1s
# 500:	learn: 0.0280712	total: 4.55s	remaining: 4.53s
# 999:	learn: 0.0175244	total: 9.01s	remaining: 0us
# 0:	learn: 0.6099212	total: 29.3ms	remaining: 29.3s
# 500:	learn: 0.0272646	total: 4.44s	remaining: 4.42s
# 999:	learn: 0.0225467	total: 8.47s	remaining: 0us
# 0:	learn: 0.6566805	total: 9.69ms	remaining: 9.68s
# 500:	learn: 0.0457433	total: 4.59s	remaining: 4.58s
# 999:	learn: 0.0268353	total: 9.12s	remaining: 0us
# 0:	learn: 0.6623169	total: 15.3ms	remaining: 15.3s
# 500:	learn: 0.0506472	total: 4.56s	remaining: 4.54s
# 999:	learn: 0.0289068	total: 9.1s	remaining: 0us
# 0:	learn: 0.6557518	total: 25.6ms	remaining: 25.6s
# 500:	learn: 0.0426090	total: 4.61s	remaining: 4.59s
# 999:	learn: 0.0262838	total: 8.98s	remaining: 0us
# 0:	learn: 0.6225156	total: 11ms	remaining: 10.9s
# 500:	learn: 0.0268149	total: 4.54s	remaining: 4.52s
# 999:	learn: 0.0150621	total: 8.98s	remaining: 0us
# 0:	learn: 0.6334201	total: 11.2ms	remaining: 11.2s
# 500:	learn: 0.0272972	total: 4.53s	remaining: 4.51s
# 999:	learn: 0.0137974	total: 8.9s	remaining: 0us
# 0:	learn: 0.6210411	total: 11.8ms	remaining: 11.8s
# 500:	learn: 0.0264460	total: 4.48s	remaining: 4.46s
# 999:	learn: 0.0169618	total: 8.7s	remaining: 0us
# 0:	learn: 0.6572845	total: 20.5ms	remaining: 20.5s
# 500:	learn: 0.0494267	total: 4.6s	remaining: 4.58s
# 999:	learn: 0.0298421	total: 9.13s	remaining: 0us
# 0:	learn: 0.6629733	total: 16.1ms	remaining: 16.1s
# 500:	learn: 0.0524642	total: 4.58s	remaining: 4.56s
# 999:	learn: 0.0305140	total: 9.09s	remaining: 0us
# 0:	learn: 0.6568365	total: 10.2ms	remaining: 10.2s
# 500:	learn: 0.0469993	total: 4.59s	remaining: 4.58s
# 999:	learn: 0.0257527	total: 9.12s	remaining: 0us
# 0:	learn: 0.6236320	total: 11.7ms	remaining: 11.7s
# 500:	learn: 0.0298366	total: 4.53s	remaining: 4.51s
# 999:	learn: 0.0174473	total: 8.87s	remaining: 0us
# 0:	learn: 0.6346238	total: 13.6ms	remaining: 13.6s
# 500:	learn: 0.0336360	total: 4.58s	remaining: 4.56s
# 999:	learn: 0.0165758	total: 8.99s	remaining: 0us
# 0:	learn: 0.6230299	total: 18.2ms	remaining: 18.2s
# 500:	learn: 0.0276011	total: 4.51s	remaining: 4.49s
# 999:	learn: 0.0162023	total: 8.97s	remaining: 0us
# 0:	learn: 0.6577759	total: 11.4ms	remaining: 11.4s
# 500:	learn: 0.0519417	total: 4.69s	remaining: 4.67s
# 999:	learn: 0.0301733	total: 9.26s	remaining: 0us
# 0:	learn: 0.6634826	total: 9.83ms	remaining: 9.82s
# 500:	learn: 0.0542621	total: 4.61s	remaining: 4.59s
# 999:	learn: 0.0316752	total: 9.15s	remaining: 0us
# 0:	learn: 0.6576879	total: 24.5ms	remaining: 24.5s
# 500:	learn: 0.0489954	total: 4.68s	remaining: 4.66s
# 999:	learn: 0.0249263	total: 9.26s	remaining: 0us
# 0:	learn: 0.6245444	total: 9.36ms	remaining: 9.35s
# 500:	learn: 0.0342342	total: 4.57s	remaining: 4.55s
# 999:	learn: 0.0175377	total: 9.04s	remaining: 0us
# 0:	learn: 0.6355626	total: 18.7ms	remaining: 18.7s
# 500:	learn: 0.0342116	total: 4.57s	remaining: 4.55s
# 999:	learn: 0.0174061	total: 9.01s	remaining: 0us
# 0:	learn: 0.6245986	total: 19.8ms	remaining: 19.8s
# 500:	learn: 0.0241846	total: 4.59s	remaining: 4.57s
# 999:	learn: 0.0179902	total: 8.74s	remaining: 0us
# 0:	learn: 0.6537563	total: 16.5ms	remaining: 16.4s
# 500:	learn: 0.0379822	total: 8.24s	remaining: 8.21s
# 999:	learn: 0.0290452	total: 15.9s	remaining: 0us
# 0:	learn: 0.6594248	total: 16.6ms	remaining: 16.6s
# 500:	learn: 0.0421611	total: 8.12s	remaining: 8.09s
# 999:	learn: 0.0276215	total: 15.5s	remaining: 0us
# 0:	learn: 0.6468106	total: 17ms	remaining: 17s
# 500:	learn: 0.0334416	total: 8.14s	remaining: 8.11s
# 999:	learn: 0.0202930	total: 16.4s	remaining: 0us
# 0:	learn: 0.6169394	total: 17.9ms	remaining: 17.9s
# 500:	learn: 0.0260302	total: 7.92s	remaining: 7.88s
# 999:	learn: 0.0142254	total: 15.9s	remaining: 0us
# 0:	learn: 0.6279357	total: 18.4ms	remaining: 18.4s
# 500:	learn: 0.0231396	total: 8.2s	remaining: 8.17s
# 999:	learn: 0.0121999	total: 16.2s	remaining: 0us
# 0:	learn: 0.6041141	total: 16.2ms	remaining: 16.2s
# 500:	learn: 0.0210139	total: 7.88s	remaining: 7.85s
# 999:	learn: 0.0117308	total: 15.6s	remaining: 0us
# 0:	learn: 0.6546999	total: 17ms	remaining: 17s
# 500:	learn: 0.0401487	total: 8.44s	remaining: 8.4s
# 999:	learn: 0.0256188	total: 16.7s	remaining: 0us
# 0:	learn: 0.6603936	total: 17.7ms	remaining: 17.6s
# 500:	learn: 0.0440540	total: 8.31s	remaining: 8.28s
# 999:	learn: 0.0241383	total: 16.9s	remaining: 0us
# 0:	learn: 0.6532839	total: 17ms	remaining: 17s
# 500:	learn: 0.0350582	total: 8.62s	remaining: 8.58s
# 999:	learn: 0.0201511	total: 17s	remaining: 0us
# 0:	learn: 0.6186736	total: 16.9ms	remaining: 16.9s
# 500:	learn: 0.0263889	total: 8.35s	remaining: 8.32s
# 999:	learn: 0.0127371	total: 16.5s	remaining: 0us
# 0:	learn: 0.6297005	total: 17.2ms	remaining: 17.2s
# 500:	learn: 0.0224646	total: 8.57s	remaining: 8.53s
# 999:	learn: 0.0122970	total: 16.9s	remaining: 0us
# 0:	learn: 0.6162393	total: 16.5ms	remaining: 16.5s
# 500:	learn: 0.0213544	total: 8.68s	remaining: 8.64s
# 999:	learn: 0.0174651	total: 16.2s	remaining: 0us
# 0:	learn: 0.6554041	total: 17ms	remaining: 17s
# 500:	learn: 0.0424277	total: 8.6s	remaining: 8.56s
# 999:	learn: 0.0243697	total: 17.1s	remaining: 0us
# 0:	learn: 0.6610592	total: 16.4ms	remaining: 16.4s
# 500:	learn: 0.0480791	total: 8.44s	remaining: 8.41s
# 999:	learn: 0.0252531	total: 17.1s	remaining: 0us
# 0:	learn: 0.6544723	total: 16.9ms	remaining: 16.9s
# 500:	learn: 0.0365649	total: 8.57s	remaining: 8.53s
# 999:	learn: 0.0194946	total: 17.2s	remaining: 0us
# 0:	learn: 0.6199767	total: 17.4ms	remaining: 17.4s
# 500:	learn: 0.0244405	total: 8.61s	remaining: 8.58s
# 999:	learn: 0.0133584	total: 16.6s	remaining: 0us
# 0:	learn: 0.6309218	total: 16.5ms	remaining: 16.5s
# 500:	learn: 0.0234052	total: 8.59s	remaining: 8.56s
# 999:	learn: 0.0109462	total: 17.1s	remaining: 0us
# 0:	learn: 0.6184206	total: 19.3ms	remaining: 19.3s
# 500:	learn: 0.0215824	total: 8.5s	remaining: 8.47s
# 999:	learn: 0.0103282	total: 17.1s	remaining: 0us
# 0:	learn: 0.6559840	total: 17.2ms	remaining: 17.2s
# 500:	learn: 0.0428716	total: 8.64s	remaining: 8.6s
# 999:	learn: 0.0251743	total: 17.1s	remaining: 0us
# 0:	learn: 0.6615754	total: 16.8ms	remaining: 16.8s
# 500:	learn: 0.0486350	total: 8.64s	remaining: 8.61s
# 999:	learn: 0.0268439	total: 17.1s	remaining: 0us
# 0:	learn: 0.6554076	total: 17ms	remaining: 17s
# 500:	learn: 0.0399254	total: 8.48s	remaining: 8.45s
# 999:	learn: 0.0208691	total: 17.1s	remaining: 0us
# 0:	learn: 0.6210545	total: 16.8ms	remaining: 16.8s
# 500:	learn: 0.0244903	total: 8.48s	remaining: 8.45s
# 999:	learn: 0.0123867	total: 16.9s	remaining: 0us
# 0:	learn: 0.6201458	total: 18.5ms	remaining: 18.5s
# 500:	learn: 0.0212875	total: 8.51s	remaining: 8.47s
# 999:	learn: 0.0103950	total: 16.9s	remaining: 0us
# 0:	learn: 0.6527501	total: 29.2ms	remaining: 29.2s
# 500:	learn: 0.0315094	total: 15.3s	remaining: 15.2s
# 999:	learn: 0.0173572	total: 30.1s	remaining: 0us
# 0:	learn: 0.6579405	total: 31.9ms	remaining: 31.9s
# 500:	learn: 0.0326622	total: 15.2s	remaining: 15.2s
# 999:	learn: 0.0174260	total: 30.2s	remaining: 0us
# 0:	learn: 0.6438640	total: 30ms	remaining: 30s
# 500:	learn: 0.0303143	total: 14.9s	remaining: 14.8s
# 999:	learn: 0.0269543	total: 25.1s	remaining: 0us
# 0:	learn: 0.6150033	total: 31.3ms	remaining: 31.3s
# 500:	learn: 0.0162692	total: 15.1s	remaining: 15.1s
# 999:	learn: 0.0091864	total: 30s	remaining: 0us
# 0:	learn: 0.6250790	total: 30.3ms	remaining: 30.2s
# 500:	learn: 0.0211444	total: 14.4s	remaining: 14.4s
# 999:	learn: 0.0082757	total: 29.6s	remaining: 0us
# 0:	learn: 0.5985268	total: 29.7ms	remaining: 29.7s
# 500:	learn: 0.0189065	total: 14.3s	remaining: 14.3s
# 999:	learn: 0.0102049	total: 27.4s	remaining: 0us
# 0:	learn: 0.6539547	total: 30.2ms	remaining: 30.1s
# 500:	learn: 0.0336920	total: 15.2s	remaining: 15.2s
# 999:	learn: 0.0171944	total: 30.3s	remaining: 0us
# 0:	learn: 0.6590806	total: 30.5ms	remaining: 30.5s
# 500:	learn: 0.0374682	total: 15.3s	remaining: 15.2s
# 999:	learn: 0.0199604	total: 30.6s	remaining: 0us
# 0:	learn: 0.6503331	total: 30.4ms	remaining: 30.4s
# 500:	learn: 0.0315002	total: 15.3s	remaining: 15.2s
# 999:	learn: 0.0186702	total: 30.5s	remaining: 0us
# 0:	learn: 0.6172231	total: 30.3ms	remaining: 30.2s
# 500:	learn: 0.0187155	total: 15.4s	remaining: 15.3s
# 999:	learn: 0.0083733	total: 30.5s	remaining: 0us
# 0:	learn: 0.6271621	total: 30.1ms	remaining: 30.1s
# 500:	learn: 0.0179302	total: 15.1s	remaining: 15s
# 999:	learn: 0.0060774	total: 30.4s	remaining: 0us
# 0:	learn: 0.6106165	total: 30ms	remaining: 30s
# 500:	learn: 0.0174694	total: 15.1s	remaining: 15s
# 999:	learn: 0.0085304	total: 28.7s	remaining: 0us
# 0:	learn: 0.6548279	total: 30.2ms	remaining: 30.2s
# 500:	learn: 0.0341219	total: 15.4s	remaining: 15.3s
# 999:	learn: 0.0190421	total: 30.7s	remaining: 0us
# 0:	learn: 0.6598619	total: 30.4ms	remaining: 30.4s
# 500:	learn: 0.0400010	total: 15.5s	remaining: 15.4s
# 999:	learn: 0.0204709	total: 30.9s	remaining: 0us
# 0:	learn: 0.6517468	total: 30.2ms	remaining: 30.2s
# 500:	learn: 0.0315790	total: 15.3s	remaining: 15.3s
# 999:	learn: 0.0182323	total: 30.7s	remaining: 0us
# 0:	learn: 0.6188434	total: 30.4ms	remaining: 30.4s
# 500:	learn: 0.0180597	total: 15.3s	remaining: 15.2s
# 999:	learn: 0.0094214	total: 30.4s	remaining: 0us
# 0:	learn: 0.6285998	total: 30.3ms	remaining: 30.3s
# 500:	learn: 0.0229937	total: 15.3s	remaining: 15.3s
# 999:	learn: 0.0079513	total: 30.6s	remaining: 0us
# 0:	learn: 0.6132115	total: 30ms	remaining: 30s
# 500:	learn: 0.0161798	total: 15.3s	remaining: 15.3s
# 999:	learn: 0.0081067	total: 30.5s	remaining: 0us
# 0:	learn: 0.6555324	total: 30.7ms	remaining: 30.7s
# 500:	learn: 0.0368862	total: 15.4s	remaining: 15.3s
# 999:	learn: 0.0209923	total: 30.7s	remaining: 0us
# 0:	learn: 0.6604671	total: 30.4ms	remaining: 30.3s
# 500:	learn: 0.0435175	total: 15.1s	remaining: 15.1s
# 999:	learn: 0.0209877	total: 30.4s	remaining: 0us
# 0:	learn: 0.6528385	total: 30.4ms	remaining: 30.4s
# 500:	learn: 0.0330987	total: 15.3s	remaining: 15.3s
# 999:	learn: 0.0161812	total: 30.8s	remaining: 0us
# 0:	learn: 0.6201566	total: 32ms	remaining: 31.9s
# 500:	learn: 0.0203131	total: 15.5s	remaining: 15.4s
# 999:	learn: 0.0102801	total: 30.5s	remaining: 0us
# 0:	learn: 0.6297191	total: 30ms	remaining: 30s
# 500:	learn: 0.0233961	total: 15.3s	remaining: 15.2s
# 999:	learn: 0.0075629	total: 30.7s	remaining: 0us
# 0:	learn: 0.6152254	total: 30.9ms	remaining: 30.9s
# 500:	learn: 0.0158898	total: 15.3s	remaining: 15.3s
# 999:	learn: 0.0086870	total: 30.1s	remaining: 0us
# 0:	learn: 0.6513432	total: 53.4ms	remaining: 53.3s
# 500:	learn: 0.0283105	total: 27.7s	remaining: 27.6s
# 999:	learn: 0.0137996	total: 54.2s	remaining: 0us
# 0:	learn: 0.6554075	total: 59.2ms	remaining: 59.1s
# 500:	learn: 0.0294329	total: 27.1s	remaining: 27s
# 999:	learn: 0.0150542	total: 55.6s	remaining: 0us
# 0:	learn: 0.6450240	total: 58.6ms	remaining: 58.5s
# 500:	learn: 0.0260979	total: 27.2s	remaining: 27.1s
# 999:	learn: 0.0161780	total: 55s	remaining: 0us
# 0:	learn: 0.6123040	total: 58ms	remaining: 57.9s
# 500:	learn: 0.0130267	total: 26.3s	remaining: 26.2s
# 999:	learn: 0.0052952	total: 54.7s	remaining: 0us
# 0:	learn: 0.6201982	total: 58.1ms	remaining: 58s
# 500:	learn: 0.0140713	total: 28s	remaining: 27.9s
# 999:	learn: 0.0058646	total: 56.8s	remaining: 0us
# 0:	learn: 0.6004953	total: 57.8ms	remaining: 57.7s
# 500:	learn: 0.0175471	total: 27.7s	remaining: 27.6s
# 999:	learn: 0.0095181	total: 55.2s	remaining: 0us
# 0:	learn: 0.6527063	total: 56.2ms	remaining: 56.2s
# 500:	learn: 0.0286002	total: 28.2s	remaining: 28.1s
# 999:	learn: 0.0181210	total: 56.6s	remaining: 0us
# 0:	learn: 0.6569934	total: 58.9ms	remaining: 58.8s
# 500:	learn: 0.0316903	total: 28.1s	remaining: 28s
# 999:	learn: 0.0154425	total: 56.8s	remaining: 0us
# 0:	learn: 0.6510119	total: 59.8ms	remaining: 59.7s
# 500:	learn: 0.0277150	total: 27.6s	remaining: 27.5s
# 999:	learn: 0.0133235	total: 56.5s	remaining: 0us
# 0:	learn: 0.6148393	total: 55.1ms	remaining: 55s
# 500:	learn: 0.0135073	total: 28.7s	remaining: 28.6s
# 999:	learn: 0.0063487	total: 56.8s	remaining: 0us
# 0:	learn: 0.6231201	total: 56.2ms	remaining: 56.1s
# 500:	learn: 0.0119198	total: 28.6s	remaining: 28.5s
# 999:	learn: 0.0049361	total: 57.2s	remaining: 0us
# 0:	learn: 0.6117096	total: 56.4ms	remaining: 56.3s
# 500:	learn: 0.0150506	total: 25.6s	remaining: 25.5s
# 999:	learn: 0.0078203	total: 54s	remaining: 0us
# 0:	learn: 0.6536667	total: 58ms	remaining: 57.9s
# 500:	learn: 0.0295223	total: 28.4s	remaining: 28.3s
# 999:	learn: 0.0176548	total: 57s	remaining: 0us
# 0:	learn: 0.6580835	total: 56.5ms	remaining: 56.5s
# 500:	learn: 0.0349584	total: 28.4s	remaining: 28.3s
# 999:	learn: 0.0135352	total: 57.2s	remaining: 0us
# 0:	learn: 0.6527184	total: 55.6ms	remaining: 55.5s
# 500:	learn: 0.0292201	total: 27.3s	remaining: 27.2s
# 999:	learn: 0.0130150	total: 56s	remaining: 0us
# 0:	learn: 0.6166228	total: 58.6ms	remaining: 58.6s
# 500:	learn: 0.0153152	total: 28.5s	remaining: 28.4s
# 999:	learn: 0.0070173	total: 57.1s	remaining: 0us
# 0:	learn: 0.6251427	total: 57.6ms	remaining: 57.6s
# 500:	learn: 0.0135111	total: 28.5s	remaining: 28.4s
# 999:	learn: 0.0051565	total: 57.2s	remaining: 0us
# 0:	learn: 0.6148771	total: 58.4ms	remaining: 58.3s
# 500:	learn: 0.0148640	total: 28.8s	remaining: 28.7s
# 999:	learn: 0.0073956	total: 57.5s	remaining: 0us
# 0:	learn: 0.6544361	total: 60.5ms	remaining: 1m
# 500:	learn: 0.0322793	total: 28.4s	remaining: 28.3s
# 999:	learn: 0.0168213	total: 57.3s	remaining: 0us
# 0:	learn: 0.6589293	total: 57.2ms	remaining: 57.2s
# 500:	learn: 0.0369637	total: 28.3s	remaining: 28.2s
# 999:	learn: 0.0157512	total: 57.3s	remaining: 0us
# 0:	learn: 0.6540418	total: 58ms	remaining: 58s
# 500:	learn: 0.0300057	total: 28.4s	remaining: 28.3s
# 999:	learn: 0.0140386	total: 57.2s	remaining: 0us
# 0:	learn: 0.6180581	total: 56.1ms	remaining: 56s
# 500:	learn: 0.0184867	total: 28.8s	remaining: 28.6s
# 999:	learn: 0.0072712	total: 57.5s	remaining: 0us
# 0:	learn: 0.6267195	total: 59.3ms	remaining: 59.2s
# 500:	learn: 0.0148148	total: 28.8s	remaining: 28.7s
# 999:	learn: 0.0049915	total: 57.6s	remaining: 0us
# 0:	learn: 0.6173456	total: 61.6ms	remaining: 1m 1s
# 500:	learn: 0.0122605	total: 28.9s	remaining: 28.8s
# 999:	learn: 0.0065718	total: 57.8s	remaining: 0us
# 0:	learn: 0.6514877	total: 102ms	remaining: 1m 41s
# 500:	learn: 0.0234352	total: 51.6s	remaining: 51.4s
# 999:	learn: 0.0095386	total: 1m 45s	remaining: 0us
# 0:	learn: 0.6547470	total: 116ms	remaining: 1m 55s
# 500:	learn: 0.0228689	total: 53.2s	remaining: 53s
# 999:	learn: 0.0102426	total: 1m 48s	remaining: 0us
# 0:	learn: 0.6453368	total: 111ms	remaining: 1m 50s
# 500:	learn: 0.0257200	total: 52.2s	remaining: 52s
# 999:	learn: 0.0144037	total: 1m 43s	remaining: 0us
# 0:	learn: 0.6125493	total: 111ms	remaining: 1m 50s
# 500:	learn: 0.0094036	total: 54.5s	remaining: 54.3s
# 999:	learn: 0.0061433	total: 1m 47s	remaining: 0us
# 0:	learn: 0.6188971	total: 112ms	remaining: 1m 51s
# 500:	learn: 0.0129374	total: 54.7s	remaining: 54.5s
# 999:	learn: 0.0045827	total: 1m 50s	remaining: 0us
# 0:	learn: 0.6010311	total: 113ms	remaining: 1m 52s
# 500:	learn: 0.0138815	total: 41s	remaining: 40.9s
# 999:	learn: 0.0066481	total: 1m 36s	remaining: 0us
# 0:	learn: 0.6529354	total: 111ms	remaining: 1m 51s
# 500:	learn: 0.0227702	total: 54.9s	remaining: 54.7s
# 999:	learn: 0.0102206	total: 1m 50s	remaining: 0us
# 0:	learn: 0.6564558	total: 112ms	remaining: 1m 52s
# 500:	learn: 0.0269186	total: 52.8s	remaining: 52.6s
# 999:	learn: 0.0100846	total: 1m 48s	remaining: 0us
# 0:	learn: 0.6516411	total: 112ms	remaining: 1m 51s
# 500:	learn: 0.0238842	total: 53.8s	remaining: 53.6s
# 999:	learn: 0.0123233	total: 1m 48s	remaining: 0us
# 0:	learn: 0.6152465	total: 113ms	remaining: 1m 52s
# 500:	learn: 0.0136809	total: 55.2s	remaining: 55s
# 999:	learn: 0.0060486	total: 1m 50s	remaining: 0us
# 0:	learn: 0.6220581	total: 114ms	remaining: 1m 53s
# 500:	learn: 0.0101181	total: 54.3s	remaining: 54.1s
# 999:	learn: 0.0040000	total: 1m 49s	remaining: 0us
# 0:	learn: 0.6128659	total: 115ms	remaining: 1m 54s
# 500:	learn: 0.0109250	total: 55s	remaining: 54.8s
# 999:	learn: 0.0060297	total: 1m 50s	remaining: 0us
# 0:	learn: 0.6541119	total: 112ms	remaining: 1m 51s
# 500:	learn: 0.0246434	total: 54.5s	remaining: 54.3s
# 999:	learn: 0.0117668	total: 1m 50s	remaining: 0us
# 0:	learn: 0.6576255	total: 112ms	remaining: 1m 51s
# 500:	learn: 0.0274898	total: 54.3s	remaining: 54.1s
# 999:	learn: 0.0122575	total: 1m 50s	remaining: 0us
# 0:	learn: 0.6534772	total: 114ms	remaining: 1m 54s
# 500:	learn: 0.0249097	total: 55s	remaining: 54.8s
# 999:	learn: 0.0127847	total: 1m 50s	remaining: 0us
# 0:	learn: 0.6174427	total: 110ms	remaining: 1m 49s
# 500:	learn: 0.0145410	total: 55.8s	remaining: 55.5s
# 999:	learn: 0.0072913	total: 1m 51s	remaining: 0us
# 0:	learn: 0.6242368	total: 113ms	remaining: 1m 52s
# 500:	learn: 0.0123205	total: 55.2s	remaining: 55s
# 999:	learn: 0.0042391	total: 1m 51s	remaining: 0us
# 0:	learn: 0.6162878	total: 110ms	remaining: 1m 50s
# 500:	learn: 0.0112896	total: 55.7s	remaining: 55.5s
# 999:	learn: 0.0055329	total: 1m 51s	remaining: 0us
# 0:	learn: 0.6550408	total: 114ms	remaining: 1m 53s
# 500:	learn: 0.0259049	total: 54.7s	remaining: 54.5s
# 999:	learn: 0.0133709	total: 1m 50s	remaining: 0us
# 0:	learn: 0.6585297	total: 112ms	remaining: 1m 51s
# 500:	learn: 0.0307611	total: 54.6s	remaining: 54.4s
# 999:	learn: 0.0118780	total: 1m 50s	remaining: 0us
# 0:	learn: 0.6539413	total: 115ms	remaining: 1m 54s
# 500:	learn: 0.0265553	total: 53.8s	remaining: 53.5s
# 999:	learn: 0.0113990	total: 1m 49s	remaining: 0us
# 0:	learn: 0.6191843	total: 112ms	remaining: 1m 52s
# 500:	learn: 0.0128883	total: 54.9s	remaining: 54.7s
# 999:	learn: 0.0054564	total: 1m 50s	remaining: 0us
# 0:	learn: 0.6259285	total: 115ms	remaining: 1m 55s
# 500:	learn: 0.0140832	total: 55s	remaining: 54.8s
# 999:	learn: 0.0042036	total: 1m 51s	remaining: 0us
# 0:	learn: 0.6171396	total: 111ms	remaining: 1m 51s
# 500:	learn: 0.0131877	total: 55.6s	remaining: 55.4s
# 999:	learn: 0.0058045	total: 1m 51s	remaining: 0us
# 0:	learn: 0.6572257	total: 12.6ms	remaining: 12.5s
# 500:	learn: 0.0353462	total: 1.84s	remaining: 1.84s
# 999:	learn: 0.0135161	total: 3.64s	remaining: 0us
# 0:	learn: 0.6567538	total: 4.88ms	remaining: 4.88s
# 500:	learn: 0.0354035	total: 1.45s	remaining: 1.44s
# 999:	learn: 0.0127993	total: 2.92s	remaining: 0us
# 0:	learn: 0.6533007	total: 9.52ms	remaining: 9.51s
# 500:	learn: 0.0330024	total: 1.7s	remaining: 1.69s
# 999:	learn: 0.0127561	total: 3.41s	remaining: 0us
# 0:	learn: 0.6236185	total: 17ms	remaining: 17s
# 500:	learn: 0.0133412	total: 1.78s	remaining: 1.77s
# 999:	learn: 0.0049749	total: 3.44s	remaining: 0us
# 0:	learn: 0.6227714	total: 29.5ms	remaining: 29.5s
# 500:	learn: 0.0126294	total: 1.46s	remaining: 1.46s
# 999:	learn: 0.0047976	total: 2.83s	remaining: 0us
# 0:	learn: 0.6165387	total: 3.34ms	remaining: 3.33s
# 500:	learn: 0.0114173	total: 1.73s	remaining: 1.72s
# 999:	learn: 0.0044913	total: 3.37s	remaining: 0us
# 0:	learn: 0.6580751	total: 6.92ms	remaining: 6.92s
# 500:	learn: 0.0391911	total: 1.82s	remaining: 1.82s
# 999:	learn: 0.0166927	total: 3.57s	remaining: 0us
# 0:	learn: 0.6574414	total: 4.86ms	remaining: 4.85s
# 500:	learn: 0.0391375	total: 1.45s	remaining: 1.45s
# 999:	learn: 0.0156123	total: 2.91s	remaining: 0us
# 0:	learn: 0.6544783	total: 10.3ms	remaining: 10.3s
# 500:	learn: 0.0364959	total: 1.75s	remaining: 1.74s
# 999:	learn: 0.0154232	total: 3.44s	remaining: 0us
# 0:	learn: 0.6251789	total: 8.01ms	remaining: 8s
# 500:	learn: 0.0158509	total: 1.78s	remaining: 1.77s
# 999:	learn: 0.0060849	total: 3.45s	remaining: 0us
# 0:	learn: 0.6240318	total: 8.77ms	remaining: 8.77s
# 500:	learn: 0.0147544	total: 1.44s	remaining: 1.44s
# 999:	learn: 0.0056404	total: 2.82s	remaining: 0us
# 0:	learn: 0.6186555	total: 7.43ms	remaining: 7.42s
# 500:	learn: 0.0146848	total: 1.73s	remaining: 1.72s
# 999:	learn: 0.0057718	total: 3.36s	remaining: 0us
# 0:	learn: 0.6586695	total: 9.02ms	remaining: 9.01s
# 500:	learn: 0.0409764	total: 1.79s	remaining: 1.78s
# 999:	learn: 0.0185543	total: 3.51s	remaining: 0us
# 0:	learn: 0.6553221	total: 20.7ms	remaining: 20.7s
# 500:	learn: 0.0391465	total: 1.73s	remaining: 1.72s
# 999:	learn: 0.0171650	total: 3.47s	remaining: 0us
# 0:	learn: 0.6262777	total: 16.8ms	remaining: 16.8s
# 500:	learn: 0.0174148	total: 1.81s	remaining: 1.8s
# 999:	learn: 0.0076475	total: 3.46s	remaining: 0us
# 0:	learn: 0.6249289	total: 25.8ms	remaining: 25.8s
# 500:	learn: 0.0171731	total: 1.48s	remaining: 1.48s
# 999:	learn: 0.0070116	total: 2.94s	remaining: 0us
# 0:	learn: 0.6201788	total: 51.5ms	remaining: 51.5s
# 500:	learn: 0.0161838	total: 1.88s	remaining: 1.87s
# 999:	learn: 0.0079994	total: 3.53s	remaining: 0us
# 0:	learn: 0.6591388	total: 18.8ms	remaining: 18.8s
# 500:	learn: 0.0440189	total: 1.71s	remaining: 1.7s
# 999:	learn: 0.0205187	total: 3.43s	remaining: 0us
# 0:	learn: 0.6583217	total: 3.23ms	remaining: 3.23s
# 500:	learn: 0.0448619	total: 1.47s	remaining: 1.46s
# 999:	learn: 0.0201233	total: 2.92s	remaining: 0us
# 0:	learn: 0.6559908	total: 30.6ms	remaining: 30.5s
# 500:	learn: 0.0412759	total: 1.74s	remaining: 1.73s
# 999:	learn: 0.0185488	total: 3.45s	remaining: 0us
# 0:	learn: 0.6271510	total: 7.65ms	remaining: 7.64s
# 500:	learn: 0.0209032	total: 1.69s	remaining: 1.68s
# 999:	learn: 0.0088562	total: 3.33s	remaining: 0us
# 0:	learn: 0.6213983	total: 11.4ms	remaining: 11.4s
# 500:	learn: 0.0176168	total: 1.72s	remaining: 1.72s
# 999:	learn: 0.0088660	total: 3.33s	remaining: 0us
# 0:	learn: 0.6593694	total: 6.23ms	remaining: 6.23s
# 500:	learn: 0.0106630	total: 2.73s	remaining: 2.72s
# 999:	learn: 0.0031145	total: 5.46s	remaining: 0us
# 0:	learn: 0.6600367	total: 5.27ms	remaining: 5.27s
# 500:	learn: 0.0110224	total: 2.73s	remaining: 2.72s
# 999:	learn: 0.0033036	total: 5.42s	remaining: 0us
# 0:	learn: 0.6618713	total: 5.93ms	remaining: 5.93s
# 500:	learn: 0.0107022	total: 2.78s	remaining: 2.77s
# 999:	learn: 0.0037009	total: 5.43s	remaining: 0us
# 0:	learn: 0.6272953	total: 7.12ms	remaining: 7.11s
# 500:	learn: 0.0029787	total: 2.72s	remaining: 2.71s
# 999:	learn: 0.0024605	total: 5.17s	remaining: 0us
# 0:	learn: 0.6285576	total: 5.41ms	remaining: 5.4s
# 500:	learn: 0.0032296	total: 2.72s	remaining: 2.71s
# 999:	learn: 0.0026700	total: 5.22s	remaining: 0us
# 0:	learn: 0.6322029	total: 5.52ms	remaining: 5.51s
# 500:	learn: 0.0034466	total: 2.7s	remaining: 2.69s
# 999:	learn: 0.0029788	total: 5.18s	remaining: 0us
# 0:	learn: 0.6595665	total: 5.99ms	remaining: 5.99s
# 500:	learn: 0.0133584	total: 2.7s	remaining: 2.69s
# 999:	learn: 0.0043670	total: 5.82s	remaining: 0us
# 0:	learn: 0.6600792	total: 5.87ms	remaining: 5.86s
# 500:	learn: 0.0134656	total: 2.98s	remaining: 2.97s
# 999:	learn: 0.0048302	total: 5.75s	remaining: 0us
# 0:	learn: 0.6622703	total: 5.4ms	remaining: 5.4s
# 500:	learn: 0.0135105	total: 2.7s	remaining: 2.69s
# 999:	learn: 0.0050971	total: 5.36s	remaining: 0us
# 0:	learn: 0.6276577	total: 6.23ms	remaining: 6.23s
# 500:	learn: 0.0040913	total: 2.68s	remaining: 2.67s
# 999:	learn: 0.0030061	total: 5.23s	remaining: 0us
# 0:	learn: 0.6286392	total: 5.38ms	remaining: 5.38s
# 500:	learn: 0.0044823	total: 2.73s	remaining: 2.72s
# 999:	learn: 0.0035467	total: 5.36s	remaining: 0us
# 0:	learn: 0.6329318	total: 5.45ms	remaining: 5.45s
# 500:	learn: 0.0048374	total: 2.69s	remaining: 2.67s
# 999:	learn: 0.0034255	total: 5.26s	remaining: 0us
# 0:	learn: 0.6597093	total: 6.63ms	remaining: 6.63s
# 500:	learn: 0.0157554	total: 2.75s	remaining: 2.74s
# 999:	learn: 0.0054170	total: 5.53s	remaining: 0us
# 0:	learn: 0.6601272	total: 5.8ms	remaining: 5.79s
# 500:	learn: 0.0169832	total: 2.74s	remaining: 2.73s
# 999:	learn: 0.0064322	total: 5.48s	remaining: 0us
# 0:	learn: 0.6624950	total: 5.5ms	remaining: 5.49s
# 500:	learn: 0.0162863	total: 2.67s	remaining: 2.66s
# 999:	learn: 0.0064746	total: 5.34s	remaining: 0us
# 0:	learn: 0.6279240	total: 7.09ms	remaining: 7.09s
# 500:	learn: 0.0050559	total: 2.73s	remaining: 2.72s
# 999:	learn: 0.0038382	total: 5.29s	remaining: 0us
# 0:	learn: 0.6287267	total: 5.24ms	remaining: 5.24s
# 500:	learn: 0.0061157	total: 2.68s	remaining: 2.67s
# 999:	learn: 0.0041775	total: 5.23s	remaining: 0us
# 0:	learn: 0.6333500	total: 5.51ms	remaining: 5.5s
# 500:	learn: 0.0058361	total: 2.66s	remaining: 2.65s
# 999:	learn: 0.0041258	total: 5.22s	remaining: 0us
# 0:	learn: 0.6598254	total: 5.99ms	remaining: 5.99s
# 500:	learn: 0.0172577	total: 2.73s	remaining: 2.72s
# 999:	learn: 0.0067322	total: 5.42s	remaining: 0us
# 0:	learn: 0.6601725	total: 5.99ms	remaining: 5.98s
# 500:	learn: 0.0185100	total: 2.74s	remaining: 2.73s
# 999:	learn: 0.0079236	total: 5.48s	remaining: 0us
# 0:	learn: 0.6628142	total: 5.29ms	remaining: 5.28s
# 500:	learn: 0.0179434	total: 2.72s	remaining: 2.71s
# 999:	learn: 0.0076737	total: 5.45s	remaining: 0us
# 0:	learn: 0.6281440	total: 6.23ms	remaining: 6.22s
# 500:	learn: 0.0062404	total: 2.72s	remaining: 2.71s
# 999:	learn: 0.0040906	total: 5.33s	remaining: 0us
# 0:	learn: 0.6288132	total: 5.46ms	remaining: 5.45s
# 500:	learn: 0.0070528	total: 2.77s	remaining: 2.76s
# 999:	learn: 0.0042516	total: 5.46s	remaining: 0us
# 0:	learn: 0.6339579	total: 5.66ms	remaining: 5.65s
# 500:	learn: 0.0079511	total: 2.7s	remaining: 2.69s
# 999:	learn: 0.0045688	total: 5.29s	remaining: 0us
# 0:	learn: 0.6567174	total: 8.44ms	remaining: 8.43s
# 500:	learn: 0.0249004	total: 2.4s	remaining: 2.38s
# 999:	learn: 0.0081693	total: 4.71s	remaining: 0us
# 0:	learn: 0.6545443	total: 29.1ms	remaining: 29s
# 500:	learn: 0.0246314	total: 1.84s	remaining: 1.83s
# 999:	learn: 0.0078566	total: 3.66s	remaining: 0us
# 0:	learn: 0.6530612	total: 5.09ms	remaining: 5.08s
# 500:	learn: 0.0231274	total: 2.36s	remaining: 2.35s
# 999:	learn: 0.0079526	total: 4.67s	remaining: 0us
# 0:	learn: 0.6226285	total: 9.55ms	remaining: 9.54s
# 500:	learn: 0.0082680	total: 2.32s	remaining: 2.31s
# 999:	learn: 0.0035124	total: 4.49s	remaining: 0us
# 0:	learn: 0.6185143	total: 16.1ms	remaining: 16.1s
# 500:	learn: 0.0078832	total: 1.84s	remaining: 1.83s
# 999:	learn: 0.0035017	total: 3.54s	remaining: 0us
# 0:	learn: 0.6160564	total: 15.6ms	remaining: 15.6s
# 500:	learn: 0.0071303	total: 2.52s	remaining: 2.52s
# 999:	learn: 0.0039438	total: 4.74s	remaining: 0us
# 0:	learn: 0.6576177	total: 8.83ms	remaining: 8.82s
# 500:	learn: 0.0282548	total: 2.3s	remaining: 2.29s
# 999:	learn: 0.0105894	total: 4.57s	remaining: 0us
# 0:	learn: 0.6554338	total: 29.1ms	remaining: 29.1s
# 500:	learn: 0.0290444	total: 1.86s	remaining: 1.85s
# 999:	learn: 0.0102914	total: 3.67s	remaining: 0us
# 0:	learn: 0.6543082	total: 9.55ms	remaining: 9.54s
# 500:	learn: 0.0268113	total: 2.23s	remaining: 2.23s
# 999:	learn: 0.0104483	total: 4.54s	remaining: 0us
# 0:	learn: 0.6242884	total: 28.6ms	remaining: 28.5s
# 500:	learn: 0.0111522	total: 2.27s	remaining: 2.26s
# 999:	learn: 0.0045520	total: 4.45s	remaining: 0us
# 0:	learn: 0.6201432	total: 19.3ms	remaining: 19.3s
# 500:	learn: 0.0096739	total: 1.89s	remaining: 1.88s
# 999:	learn: 0.0043413	total: 3.6s	remaining: 0us
# 0:	learn: 0.6183084	total: 16.4ms	remaining: 16.4s
# 500:	learn: 0.0094467	total: 2.32s	remaining: 2.31s
# 999:	learn: 0.0047801	total: 4.47s	remaining: 0us
# 0:	learn: 0.6582557	total: 11.9ms	remaining: 11.9s
# 500:	learn: 0.0313565	total: 2.36s	remaining: 2.35s
# 999:	learn: 0.0126792	total: 4.61s	remaining: 0us
# 0:	learn: 0.6560712	total: 27.5ms	remaining: 27.4s
# 500:	learn: 0.0313484	total: 1.87s	remaining: 1.86s
# 999:	learn: 0.0120282	total: 3.68s	remaining: 0us
# 0:	learn: 0.6551993	total: 7.74ms	remaining: 7.73s
# 500:	learn: 0.0301181	total: 2.27s	remaining: 2.27s
# 999:	learn: 0.0119691	total: 4.63s	remaining: 0us
# 0:	learn: 0.6254753	total: 4.31ms	remaining: 4.3s
# 500:	learn: 0.0132828	total: 2.25s	remaining: 2.24s
# 999:	learn: 0.0052368	total: 4.44s	remaining: 0us
# 0:	learn: 0.6213267	total: 12.4ms	remaining: 12.4s
# 500:	learn: 0.0113378	total: 1.82s	remaining: 1.81s
# 999:	learn: 0.0051259	total: 3.53s	remaining: 0us
# 0:	learn: 0.6199183	total: 35.3ms	remaining: 35.2s
# 500:	learn: 0.0117734	total: 2.3s	remaining: 2.29s
# 999:	learn: 0.0045800	total: 4.47s	remaining: 0us
# 0:	learn: 0.6587654	total: 7.75ms	remaining: 7.74s
# 500:	learn: 0.0344243	total: 2.39s	remaining: 2.38s
# 999:	learn: 0.0151480	total: 4.69s	remaining: 0us
# 0:	learn: 0.6565898	total: 17.3ms	remaining: 17.3s
# 500:	learn: 0.0340582	total: 1.83s	remaining: 1.83s
# 999:	learn: 0.0132158	total: 3.64s	remaining: 0us
# 0:	learn: 0.6558997	total: 7.93ms	remaining: 7.92s
# 500:	learn: 0.0321397	total: 2.24s	remaining: 2.23s
# 999:	learn: 0.0141795	total: 4.51s	remaining: 0us
# 0:	learn: 0.6264301	total: 11.2ms	remaining: 11.2s
# 500:	learn: 0.0154957	total: 2.29s	remaining: 2.28s
# 999:	learn: 0.0068422	total: 4.42s	remaining: 0us
# 0:	learn: 0.6222822	total: 35.2ms	remaining: 35.1s
# 500:	learn: 0.0131894	total: 1.85s	remaining: 1.85s
# 999:	learn: 0.0056124	total: 3.61s	remaining: 0us
# 0:	learn: 0.6212063	total: 18.8ms	remaining: 18.8s
# 500:	learn: 0.0137234	total: 2.25s	remaining: 2.24s
# 999:	learn: 0.0069536	total: 4.38s	remaining: 0us
# 0:	learn: 0.6571266	total: 5.82ms	remaining: 5.82s
# 500:	learn: 0.0099955	total: 2.83s	remaining: 2.82s
# 999:	learn: 0.0027033	total: 5.63s	remaining: 0us
# 0:	learn: 0.6607920	total: 5.94ms	remaining: 5.94s
# 500:	learn: 0.0096112	total: 2.88s	remaining: 2.87s
# 999:	learn: 0.0026108	total: 5.74s	remaining: 0us
# 0:	learn: 0.6619297	total: 5.6ms	remaining: 5.6s
# 500:	learn: 0.0088127	total: 2.93s	remaining: 2.92s
# 999:	learn: 0.0027199	total: 5.78s	remaining: 0us
# 0:	learn: 0.6230043	total: 5.88ms	remaining: 5.88s
# 500:	learn: 0.0026549	total: 2.88s	remaining: 2.87s
# 999:	learn: 0.0021443	total: 5.8s	remaining: 0us
# 0:	learn: 0.6299898	total: 6.89ms	remaining: 6.88s
# 500:	learn: 0.0026018	total: 2.94s	remaining: 2.93s
# 999:	learn: 0.0020311	total: 6.09s	remaining: 0us
# 0:	learn: 0.6322262	total: 6.03ms	remaining: 6.02s
# 500:	learn: 0.0027623	total: 3.28s	remaining: 3.27s
# 999:	learn: 0.0023844	total: 6.5s	remaining: 0us
# 0:	learn: 0.6573576	total: 6.74ms	remaining: 6.74s
# 500:	learn: 0.0122317	total: 3.65s	remaining: 3.63s
# 999:	learn: 0.0037478	total: 6.83s	remaining: 0us
# 0:	learn: 0.6609195	total: 6.22ms	remaining: 6.21s
# 500:	learn: 0.0115798	total: 3.03s	remaining: 3.01s
# 999:	learn: 0.0035266	total: 6.02s	remaining: 0us
# 0:	learn: 0.6636985	total: 6.24ms	remaining: 6.23s
# 500:	learn: 0.0110543	total: 3.49s	remaining: 3.48s
# 999:	learn: 0.0035007	total: 6.92s	remaining: 0us
# 0:	learn: 0.6234351	total: 6.45ms	remaining: 6.44s
# 500:	learn: 0.0036597	total: 3.22s	remaining: 3.2s
# 999:	learn: 0.0028577	total: 6.2s	remaining: 0us
# 0:	learn: 0.6302272	total: 6.69ms	remaining: 6.69s
# 500:	learn: 0.0035003	total: 3.17s	remaining: 3.15s
# 999:	learn: 0.0027360	total: 6s	remaining: 0us
# 0:	learn: 0.6356183	total: 5.54ms	remaining: 5.54s
# 500:	learn: 0.0037070	total: 2.82s	remaining: 2.81s
# 999:	learn: 0.0028177	total: 5.57s	remaining: 0us
# 0:	learn: 0.6575317	total: 6.46ms	remaining: 6.46s
# 500:	learn: 0.0142749	total: 2.9s	remaining: 2.89s
# 999:	learn: 0.0048705	total: 5.81s	remaining: 0us
# 0:	learn: 0.6610295	total: 5.59ms	remaining: 5.58s
# 500:	learn: 0.0132633	total: 2.98s	remaining: 2.97s
# 999:	learn: 0.0044429	total: 5.88s	remaining: 0us
# 0:	learn: 0.6637728	total: 5.55ms	remaining: 5.54s
# 500:	learn: 0.0123139	total: 2.82s	remaining: 2.81s
# 999:	learn: 0.0041335	total: 5.62s	remaining: 0us
# 0:	learn: 0.6237622	total: 5.86ms	remaining: 5.85s
# 500:	learn: 0.0046995	total: 2.93s	remaining: 2.92s
# 999:	learn: 0.0030613	total: 5.71s	remaining: 0us
# 0:	learn: 0.6304359	total: 5.81ms	remaining: 5.8s
# 500:	learn: 0.0043383	total: 2.83s	remaining: 2.82s
# 999:	learn: 0.0030662	total: 5.59s	remaining: 0us
# 0:	learn: 0.6357579	total: 5.71ms	remaining: 5.7s
# 500:	learn: 0.0045560	total: 2.82s	remaining: 2.81s
# 999:	learn: 0.0034250	total: 5.61s	remaining: 0us
# 0:	learn: 0.6588753	total: 7.34ms	remaining: 7.33s
# 500:	learn: 0.0152537	total: 2.9s	remaining: 2.88s
# 999:	learn: 0.0056549	total: 5.76s	remaining: 0us
# 0:	learn: 0.6611311	total: 6.55ms	remaining: 6.54s
# 500:	learn: 0.0146475	total: 2.88s	remaining: 2.87s
# 999:	learn: 0.0054342	total: 5.75s	remaining: 0us
# 0:	learn: 0.6638329	total: 5.49ms	remaining: 5.48s
# 500:	learn: 0.0141915	total: 2.9s	remaining: 2.89s
# 999:	learn: 0.0052847	total: 5.69s	remaining: 0us
# 0:	learn: 0.6263206	total: 5.57ms	remaining: 5.56s
# 500:	learn: 0.0054666	total: 2.94s	remaining: 2.93s
# 999:	learn: 0.0035146	total: 5.74s	remaining: 0us
# 0:	learn: 0.6306287	total: 5.82ms	remaining: 5.82s
# 500:	learn: 0.0048756	total: 2.89s	remaining: 2.88s
# 999:	learn: 0.0033754	total: 5.68s	remaining: 0us
# 0:	learn: 0.6358745	total: 6.73ms	remaining: 6.72s
# 500:	learn: 0.0052706	total: 2.89s	remaining: 2.88s
# 999:	learn: 0.0038653	total: 5.71s	remaining: 0us
# 0:	learn: 0.6551299	total: 14.3ms	remaining: 14.3s
# 500:	learn: 0.0165462	total: 3.48s	remaining: 3.47s
# 999:	learn: 0.0054635	total: 6.75s	remaining: 0us
# 0:	learn: 0.6521379	total: 11.4ms	remaining: 11.4s
# 500:	learn: 0.0174451	total: 2.58s	remaining: 2.57s
# 999:	learn: 0.0051683	total: 5.18s	remaining: 0us
# 0:	learn: 0.6495465	total: 16.5ms	remaining: 16.5s
# 500:	learn: 0.0156183	total: 3.58s	remaining: 3.56s
# 999:	learn: 0.0051323	total: 6.93s	remaining: 0us
# 0:	learn: 0.6196332	total: 11.1ms	remaining: 11s
# 500:	learn: 0.0054273	total: 3.42s	remaining: 3.41s
# 999:	learn: 0.0028923	total: 6.66s	remaining: 0us
# 0:	learn: 0.6139649	total: 33.4ms	remaining: 33.3s
# 500:	learn: 0.0049652	total: 2.53s	remaining: 2.52s
# 999:	learn: 0.0027537	total: 4.89s	remaining: 0us
# 0:	learn: 0.6092441	total: 7.05ms	remaining: 7.04s
# 500:	learn: 0.0048143	total: 3.42s	remaining: 3.4s
# 999:	learn: 0.0028417	total: 6.6s	remaining: 0us
# 0:	learn: 0.6561617	total: 25ms	remaining: 25s
# 500:	learn: 0.0208078	total: 3.34s	remaining: 3.32s
# 999:	learn: 0.0076589	total: 6.74s	remaining: 0us
# 0:	learn: 0.6531849	total: 17.9ms	remaining: 17.9s
# 500:	learn: 0.0210375	total: 2.52s	remaining: 2.52s
# 999:	learn: 0.0070988	total: 5.02s	remaining: 0us
# 0:	learn: 0.6513113	total: 35ms	remaining: 35s
# 500:	learn: 0.0195304	total: 3.34s	remaining: 3.33s
# 999:	learn: 0.0069398	total: 6.76s	remaining: 0us
# 0:	learn: 0.6215446	total: 5.62ms	remaining: 5.61s
# 500:	learn: 0.0073264	total: 3.48s	remaining: 3.47s
# 999:	learn: 0.0037935	total: 6.73s	remaining: 0us
# 0:	learn: 0.6158823	total: 11.4ms	remaining: 11.4s
# 500:	learn: 0.0070198	total: 2.53s	remaining: 2.52s
# 999:	learn: 0.0034899	total: 4.9s	remaining: 0us
# 0:	learn: 0.6124591	total: 17.2ms	remaining: 17.2s
# 500:	learn: 0.0072519	total: 3.36s	remaining: 3.35s
# 999:	learn: 0.0034553	total: 6.92s	remaining: 0us
# 0:	learn: 0.6569306	total: 21.9ms	remaining: 21.9s
# 500:	learn: 0.0238021	total: 3.41s	remaining: 3.39s
# 999:	learn: 0.0093342	total: 6.64s	remaining: 0us
# 0:	learn: 0.6539343	total: 21.6ms	remaining: 21.6s
# 500:	learn: 0.0236850	total: 2.55s	remaining: 2.54s
# 999:	learn: 0.0087264	total: 5.05s	remaining: 0us
# 0:	learn: 0.6525304	total: 16.4ms	remaining: 16.4s
# 500:	learn: 0.0223671	total: 3.35s	remaining: 3.34s
# 999:	learn: 0.0085109	total: 6.59s	remaining: 0us
# 0:	learn: 0.6229688	total: 13ms	remaining: 12.9s
# 500:	learn: 0.0088871	total: 3.4s	remaining: 3.38s
# 999:	learn: 0.0040349	total: 6.63s	remaining: 0us
# 0:	learn: 0.6172614	total: 7.97ms	remaining: 7.96s
# 500:	learn: 0.0080882	total: 2.51s	remaining: 2.5s
# 999:	learn: 0.0039886	total: 4.89s	remaining: 0us
# 0:	learn: 0.6146914	total: 29.7ms	remaining: 29.7s
# 500:	learn: 0.0087120	total: 3.37s	remaining: 3.35s
# 999:	learn: 0.0043143	total: 6.63s	remaining: 0us
# 0:	learn: 0.6575643	total: 21.5ms	remaining: 21.5s
# 500:	learn: 0.0262263	total: 3.42s	remaining: 3.41s
# 999:	learn: 0.0105537	total: 6.87s	remaining: 0us
# 0:	learn: 0.6545381	total: 20.3ms	remaining: 20.2s
# 500:	learn: 0.0256352	total: 2.54s	remaining: 2.53s
# 999:	learn: 0.0098359	total: 5.03s	remaining: 0us
# 0:	learn: 0.6534790	total: 6.65ms	remaining: 6.64s
# 500:	learn: 0.0248782	total: 3.57s	remaining: 3.56s
# 999:	learn: 0.0101636	total: 7.15s	remaining: 0us
# 0:	learn: 0.6241599	total: 17.3ms	remaining: 17.3s
# 500:	learn: 0.0104074	total: 3.42s	remaining: 3.41s
# 999:	learn: 0.0051688	total: 6.64s	remaining: 0us
# 0:	learn: 0.6183846	total: 14.5ms	remaining: 14.5s
# 500:	learn: 0.0097601	total: 2.52s	remaining: 2.51s
# 999:	learn: 0.0044694	total: 4.94s	remaining: 0us
# 0:	learn: 0.6164348	total: 5.6ms	remaining: 5.6s
# 500:	learn: 0.0101273	total: 3.28s	remaining: 3.27s
# 999:	learn: 0.0041975	total: 6.52s	remaining: 0us
# 0:	learn: 0.6601169	total: 6.41ms	remaining: 6.4s
# 500:	learn: 0.0096849	total: 2.98s	remaining: 2.97s
# 999:	learn: 0.0027564	total: 5.97s	remaining: 0us
# 0:	learn: 0.6560170	total: 6.88ms	remaining: 6.87s
# 500:	learn: 0.0091328	total: 2.95s	remaining: 2.94s
# 999:	learn: 0.0024773	total: 5.89s	remaining: 0us
# 0:	learn: 0.6633367	total: 5.87ms	remaining: 5.86s
# 500:	learn: 0.0086703	total: 3.02s	remaining: 3.01s
# 999:	learn: 0.0024593	total: 6s	remaining: 0us
# 0:	learn: 0.6286668	total: 6.2ms	remaining: 6.2s
# 500:	learn: 0.0026596	total: 2.96s	remaining: 2.95s
# 999:	learn: 0.0022561	total: 5.77s	remaining: 0us
# 0:	learn: 0.6210427	total: 6.88ms	remaining: 6.87s
# 500:	learn: 0.0026041	total: 2.96s	remaining: 2.94s
# 999:	learn: 0.0021933	total: 5.63s	remaining: 0us
# 0:	learn: 0.6349216	total: 5.63ms	remaining: 5.62s
# 500:	learn: 0.0025231	total: 3.02s	remaining: 3.01s
# 999:	learn: 0.0021358	total: 5.99s	remaining: 0us
# 0:	learn: 0.6602706	total: 6.29ms	remaining: 6.28s
# 500:	learn: 0.0118399	total: 2.99s	remaining: 2.98s
# 999:	learn: 0.0035407	total: 6s	remaining: 0us
# 0:	learn: 0.6561096	total: 6.26ms	remaining: 6.25s
# 500:	learn: 0.0115595	total: 3s	remaining: 2.99s
# 999:	learn: 0.0031885	total: 5.98s	remaining: 0us
# 0:	learn: 0.6636523	total: 6.03ms	remaining: 6.03s
# 500:	learn: 0.0103683	total: 2.99s	remaining: 2.97s
# 999:	learn: 0.0032450	total: 6.01s	remaining: 0us
# 0:	learn: 0.6289551	total: 5.67ms	remaining: 5.66s
# 500:	learn: 0.0035062	total: 3.01s	remaining: 3s
# 999:	learn: 0.0026769	total: 5.91s	remaining: 0us
# 0:	learn: 0.6212187	total: 5.95ms	remaining: 5.94s
# 500:	learn: 0.0031598	total: 3s	remaining: 2.98s
# 999:	learn: 0.0026047	total: 5.96s	remaining: 0us
# 0:	learn: 0.6355193	total: 6.49ms	remaining: 6.48s
# 500:	learn: 0.0031458	total: 3.2s	remaining: 3.19s
# 999:	learn: 0.0025354	total: 6.21s	remaining: 0us
# 0:	learn: 0.6603769	total: 5.62ms	remaining: 5.62s
# 500:	learn: 0.0137042	total: 3.06s	remaining: 3.04s
# 999:	learn: 0.0042957	total: 6.08s	remaining: 0us
# 0:	learn: 0.6562049	total: 6.16ms	remaining: 6.15s
# 500:	learn: 0.0126657	total: 2.98s	remaining: 2.97s
# 999:	learn: 0.0038546	total: 5.98s	remaining: 0us
# 0:	learn: 0.6637271	total: 6.38ms	remaining: 6.38s
# 500:	learn: 0.0121525	total: 2.99s	remaining: 2.97s
# 999:	learn: 0.0038341	total: 6.05s	remaining: 0us
# 0:	learn: 0.6291562	total: 5.96ms	remaining: 5.96s
# 500:	learn: 0.0043212	total: 3.04s	remaining: 3.03s
# 999:	learn: 0.0030692	total: 6.35s	remaining: 0us
# 0:	learn: 0.6213984	total: 6.81ms	remaining: 6.8s
# 500:	learn: 0.0038756	total: 3.29s	remaining: 3.27s
# 999:	learn: 0.0030189	total: 6.23s	remaining: 0us
# 0:	learn: 0.6356633	total: 6.54ms	remaining: 6.53s
# 500:	learn: 0.0038060	total: 3.01s	remaining: 3s
# 999:	learn: 0.0029546	total: 5.88s	remaining: 0us
# 0:	learn: 0.6601801	total: 6.03ms	remaining: 6.03s
# 500:	learn: 0.0151009	total: 3.01s	remaining: 3s
# 999:	learn: 0.0050667	total: 6.03s	remaining: 0us
# 0:	learn: 0.6563100	total: 6.19ms	remaining: 6.18s
# 500:	learn: 0.0143014	total: 2.99s	remaining: 2.98s
# 999:	learn: 0.0044142	total: 5.95s	remaining: 0us
# 0:	learn: 0.6637887	total: 5.73ms	remaining: 5.73s
# 500:	learn: 0.0138174	total: 2.94s	remaining: 2.93s
# 999:	learn: 0.0044826	total: 5.94s	remaining: 0us
# 0:	learn: 0.6287777	total: 5.91ms	remaining: 5.9s
# 500:	learn: 0.0050570	total: 2.97s	remaining: 2.96s
# 999:	learn: 0.0035988	total: 5.8s	remaining: 0us
# 0:	learn: 0.6215927	total: 6.38ms	remaining: 6.38s
# 500:	learn: 0.0047546	total: 3s	remaining: 2.98s
# 999:	learn: 0.0032652	total: 5.86s	remaining: 0us
# 0:	learn: 0.6357828	total: 6.08ms	remaining: 6.07s
# 500:	learn: 0.0045518	total: 3.04s	remaining: 3.03s
# 999:	learn: 0.0031651	total: 5.98s	remaining: 0us
# 0:	learn: 0.6500818	total: 25.9ms	remaining: 25.9s
# 500:	learn: 0.0118936	total: 5.88s	remaining: 5.86s
# 999:	learn: 0.0037074	total: 10.9s	remaining: 0us
# 0:	learn: 0.6500240	total: 11.3ms	remaining: 11.3s
# 500:	learn: 0.0110089	total: 3.87s	remaining: 3.85s
# 999:	learn: 0.0034725	total: 7.69s	remaining: 0us
# 0:	learn: 0.6496873	total: 10ms	remaining: 10s
# 500:	learn: 0.0113331	total: 5.03s	remaining: 5.01s
# 999:	learn: 0.0038101	total: 9.99s	remaining: 0us
# 0:	learn: 0.6101706	total: 8.77ms	remaining: 8.76s
# 500:	learn: 0.0036886	total: 4.99s	remaining: 4.96s
# 999:	learn: 0.0024750	total: 9.77s	remaining: 0us
# 0:	learn: 0.6100427	total: 22.6ms	remaining: 22.6s
# 500:	learn: 0.0036485	total: 3.84s	remaining: 3.82s
# 999:	learn: 0.0023783	total: 7.46s	remaining: 0us
# 0:	learn: 0.6093632	total: 41.5ms	remaining: 41.4s
# 500:	learn: 0.0036640	total: 5.11s	remaining: 5.09s
# 999:	learn: 0.0026221	total: 9.96s	remaining: 0us
# 0:	learn: 0.6521140	total: 33.5ms	remaining: 33.5s
# 500:	learn: 0.0154887	total: 5.04s	remaining: 5.03s
# 999:	learn: 0.0055075	total: 10s	remaining: 0us
# 0:	learn: 0.6518970	total: 22ms	remaining: 22s
# 500:	learn: 0.0150145	total: 3.97s	remaining: 3.96s
# 999:	learn: 0.0051107	total: 7.85s	remaining: 0us
# 0:	learn: 0.6518665	total: 21.7ms	remaining: 21.7s
# 500:	learn: 0.0154178	total: 5.05s	remaining: 5.03s
# 999:	learn: 0.0050791	total: 10.1s	remaining: 0us
# 0:	learn: 0.6138989	total: 34.2ms	remaining: 34.1s
# 500:	learn: 0.0054484	total: 5.07s	remaining: 5.04s
# 999:	learn: 0.0030297	total: 10.1s	remaining: 0us
# 0:	learn: 0.6134749	total: 8.57ms	remaining: 8.56s
# 500:	learn: 0.0049577	total: 3.85s	remaining: 3.84s
# 999:	learn: 0.0029689	total: 7.53s	remaining: 0us
# 0:	learn: 0.6133708	total: 10.4ms	remaining: 10.4s
# 500:	learn: 0.0051858	total: 5.01s	remaining: 4.99s
# 999:	learn: 0.0029735	total: 9.97s	remaining: 0us
# 0:	learn: 0.6535448	total: 8.63ms	remaining: 8.63s
# 500:	learn: 0.0181840	total: 5.21s	remaining: 5.19s
# 999:	learn: 0.0066354	total: 10.3s	remaining: 0us
# 0:	learn: 0.6532044	total: 9.44ms	remaining: 9.43s
# 500:	learn: 0.0181569	total: 3.83s	remaining: 3.82s
# 999:	learn: 0.0066886	total: 7.66s	remaining: 0us
# 0:	learn: 0.6533765	total: 23.8ms	remaining: 23.8s
# 500:	learn: 0.0175251	total: 5.14s	remaining: 5.12s
# 999:	learn: 0.0063575	total: 10.2s	remaining: 0us
# 0:	learn: 0.6165459	total: 24.4ms	remaining: 24.4s
# 500:	learn: 0.0067203	total: 5.23s	remaining: 5.21s
# 999:	learn: 0.0036720	total: 10.2s	remaining: 0us
# 0:	learn: 0.6158886	total: 23ms	remaining: 23s
# 500:	learn: 0.0063251	total: 3.83s	remaining: 3.82s
# 999:	learn: 0.0034360	total: 7.54s	remaining: 0us
# 0:	learn: 0.6161674	total: 9.97ms	remaining: 9.96s
# 500:	learn: 0.0062926	total: 5.16s	remaining: 5.14s
# 999:	learn: 0.0032024	total: 10.1s	remaining: 0us
# 0:	learn: 0.6546757	total: 9.8ms	remaining: 9.79s
# 500:	learn: 0.0201819	total: 5.12s	remaining: 5.1s
# 999:	learn: 0.0079838	total: 10.3s	remaining: 0us
# 0:	learn: 0.6542337	total: 13.9ms	remaining: 13.9s
# 500:	learn: 0.0202291	total: 3.85s	remaining: 3.84s
# 999:	learn: 0.0076746	total: 7.87s	remaining: 0us
# 0:	learn: 0.6545562	total: 8.89ms	remaining: 8.88s
# 500:	learn: 0.0210449	total: 5.98s	remaining: 5.96s
# 999:	learn: 0.0079665	total: 11.4s	remaining: 0us
# 0:	learn: 0.6186443	total: 18.2ms	remaining: 18.2s
# 500:	learn: 0.0077616	total: 5.55s	remaining: 5.53s
# 999:	learn: 0.0035175	total: 11s	remaining: 0us
# 0:	learn: 0.6177935	total: 16ms	remaining: 16s
# 500:	learn: 0.0073837	total: 3.84s	remaining: 3.83s
# 999:	learn: 0.0039461	total: 7.59s	remaining: 0us
# 0:	learn: 0.6183574	total: 23ms	remaining: 23s
# 500:	learn: 0.0080459	total: 5.55s	remaining: 5.53s
# 999:	learn: 0.0037922	total: 11.1s	remaining: 0us
# 0:	learn: 0.6589600	total: 7.16ms	remaining: 7.16s
# 500:	learn: 0.0096285	total: 3.06s	remaining: 3.05s
# 999:	learn: 0.0027085	total: 6.12s	remaining: 0us
# 0:	learn: 0.6588837	total: 6.26ms	remaining: 6.25s
# 500:	learn: 0.0091807	total: 3.07s	remaining: 3.06s
# 999:	learn: 0.0024933	total: 6.09s	remaining: 0us
# 0:	learn: 0.6632037	total: 6.03ms	remaining: 6.03s
# 500:	learn: 0.0084663	total: 3.1s	remaining: 3.09s
# 999:	learn: 0.0025563	total: 6.17s	remaining: 0us
# 0:	learn: 0.6264454	total: 6.72ms	remaining: 6.71s
# 500:	learn: 0.0027069	total: 3.04s	remaining: 3.02s
# 999:	learn: 0.0022046	total: 6.02s	remaining: 0us
# 0:	learn: 0.6263313	total: 6.3ms	remaining: 6.29s
# 500:	learn: 0.0026349	total: 3.09s	remaining: 3.08s
# 999:	learn: 0.0022569	total: 5.89s	remaining: 0us
# 0:	learn: 0.6346777	total: 7.6ms	remaining: 7.59s
# 500:	learn: 0.0024237	total: 3.18s	remaining: 3.17s
# 999:	learn: 0.0021847	total: 6.04s	remaining: 0us
# 0:	learn: 0.6600378	total: 6.63ms	remaining: 6.63s
# 500:	learn: 0.0115867	total: 3.12s	remaining: 3.11s
# 999:	learn: 0.0037548	total: 6.23s	remaining: 0us
# 0:	learn: 0.6589798	total: 6.29ms	remaining: 6.28s
# 500:	learn: 0.0110463	total: 3.1s	remaining: 3.08s
# 999:	learn: 0.0033400	total: 6.16s	remaining: 0us
# 0:	learn: 0.6633589	total: 6ms	remaining: 5.99s
# 500:	learn: 0.0105474	total: 3.06s	remaining: 3.05s
# 999:	learn: 0.0032233	total: 6.15s	remaining: 0us
# 0:	learn: 0.6285008	total: 6.68ms	remaining: 6.67s
# 500:	learn: 0.0036076	total: 3.12s	remaining: 3.11s
# 999:	learn: 0.0026598	total: 6.14s	remaining: 0us
# 0:	learn: 0.6265147	total: 6.13ms	remaining: 6.13s
# 500:	learn: 0.0032328	total: 3.02s	remaining: 3.01s
# 999:	learn: 0.0024444	total: 5.92s	remaining: 0us
# 0:	learn: 0.6349629	total: 6.13ms	remaining: 6.12s
# 500:	learn: 0.0032487	total: 3.08s	remaining: 3.06s
# 999:	learn: 0.0025468	total: 6.02s	remaining: 0us
# 0:	learn: 0.6601579	total: 5.75ms	remaining: 5.75s
# 500:	learn: 0.0136765	total: 3.56s	remaining: 3.55s
# 999:	learn: 0.0044053	total: 6.83s	remaining: 0us
# 0:	learn: 0.6590561	total: 6.27ms	remaining: 6.26s
# 500:	learn: 0.0128596	total: 3.03s	remaining: 3.02s
# 999:	learn: 0.0038816	total: 6.19s	remaining: 0us
# 0:	learn: 0.6634288	total: 6.12ms	remaining: 6.12s
# 500:	learn: 0.0121754	total: 3.03s	remaining: 3.02s
# 999:	learn: 0.0038099	total: 6.15s	remaining: 0us
# 0:	learn: 0.6287270	total: 6.64ms	remaining: 6.63s
# 500:	learn: 0.0042127	total: 3.12s	remaining: 3.1s
# 999:	learn: 0.0034744	total: 5.98s	remaining: 0us
# 0:	learn: 0.6266560	total: 6.23ms	remaining: 6.22s
# 500:	learn: 0.0036538	total: 3.05s	remaining: 3.03s
# 999:	learn: 0.0028876	total: 5.95s	remaining: 0us
# 0:	learn: 0.6350962	total: 5.96ms	remaining: 5.96s
# 500:	learn: 0.0038402	total: 3.08s	remaining: 3.07s
# 999:	learn: 0.0026468	total: 6.06s	remaining: 0us
# 0:	learn: 0.6582244	total: 6.76ms	remaining: 6.75s
# 500:	learn: 0.0146655	total: 3.09s	remaining: 3.08s
# 999:	learn: 0.0049691	total: 6.21s	remaining: 0us
# 0:	learn: 0.6591112	total: 6.02ms	remaining: 6.02s
# 500:	learn: 0.0140949	total: 3.06s	remaining: 3.04s
# 999:	learn: 0.0045592	total: 6.12s	remaining: 0us
# 0:	learn: 0.6635023	total: 6.43ms	remaining: 6.42s
# 500:	learn: 0.0133377	total: 3.12s	remaining: 3.11s
# 999:	learn: 0.0044949	total: 6.26s	remaining: 0us
# 0:	learn: 0.6250688	total: 6.33ms	remaining: 6.32s
# 500:	learn: 0.0049142	total: 3.14s	remaining: 3.13s
# 999:	learn: 0.0035594	total: 6.1s	remaining: 0us
# 0:	learn: 0.6267549	total: 6.33ms	remaining: 6.33s
# 500:	learn: 0.0043726	total: 3.1s	remaining: 3.09s
# 999:	learn: 0.0031825	total: 6.09s	remaining: 0us
# 0:	learn: 0.6352292	total: 6.57ms	remaining: 6.56s
# 500:	learn: 0.0047580	total: 3.1s	remaining: 3.09s
# 999:	learn: 0.0031878	total: 6.05s	remaining: 0us
# 0:	learn: 0.6498227	total: 16.4ms	remaining: 16.4s
# 500:	learn: 0.0083640	total: 8.83s	remaining: 8.79s
# 999:	learn: 0.0030287	total: 17.5s	remaining: 0us
# 0:	learn: 0.6507871	total: 17.9ms	remaining: 17.9s
# 500:	learn: 0.0082470	total: 8.87s	remaining: 8.83s
# 999:	learn: 0.0027766	total: 17.7s	remaining: 0us
# 0:	learn: 0.6499875	total: 18.4ms	remaining: 18.4s
# 500:	learn: 0.0081324	total: 8.95s	remaining: 8.91s
# 999:	learn: 0.0029080	total: 17.8s	remaining: 0us
# 0:	learn: 0.6095174	total: 17.7ms	remaining: 17.7s
# 500:	learn: 0.0028699	total: 8.83s	remaining: 8.79s
# 999:	learn: 0.0023054	total: 17.4s	remaining: 0us
# 0:	learn: 0.6114027	total: 17ms	remaining: 17s
# 500:	learn: 0.0027778	total: 8.81s	remaining: 8.78s
# 999:	learn: 0.0022997	total: 17.4s	remaining: 0us
# 0:	learn: 0.6097565	total: 20.7ms	remaining: 20.6s
# 500:	learn: 0.0029712	total: 8.82s	remaining: 8.79s
# 999:	learn: 0.0022904	total: 17.4s	remaining: 0us
# 0:	learn: 0.6526652	total: 18.3ms	remaining: 18.2s
# 500:	learn: 0.0115374	total: 8.87s	remaining: 8.83s
# 999:	learn: 0.0043569	total: 17.7s	remaining: 0us
# 0:	learn: 0.6531100	total: 17.9ms	remaining: 17.8s
# 500:	learn: 0.0114719	total: 8.86s	remaining: 8.82s
# 999:	learn: 0.0039381	total: 17.7s	remaining: 0us
# 0:	learn: 0.6527977	total: 19.2ms	remaining: 19.2s
# 500:	learn: 0.0112611	total: 8.84s	remaining: 8.81s
# 999:	learn: 0.0040220	total: 17.7s	remaining: 0us
# 0:	learn: 0.6147914	total: 18.9ms	remaining: 18.8s
# 500:	learn: 0.0043304	total: 8.94s	remaining: 8.9s
# 999:	learn: 0.0025955	total: 17.6s	remaining: 0us
# 0:	learn: 0.6156956	total: 17.4ms	remaining: 17.4s
# 500:	learn: 0.0037991	total: 8.89s	remaining: 8.86s
# 999:	learn: 0.0025511	total: 17.5s	remaining: 0us
# 0:	learn: 0.6149805	total: 17.5ms	remaining: 17.5s
# 500:	learn: 0.0039134	total: 8.84s	remaining: 8.81s
# 999:	learn: 0.0028060	total: 17.5s	remaining: 0us
# 0:	learn: 0.6546441	total: 19.2ms	remaining: 19.2s
# 500:	learn: 0.0142406	total: 8.87s	remaining: 8.83s
# 999:	learn: 0.0053728	total: 17.7s	remaining: 0us
# 0:	learn: 0.6547298	total: 18.1ms	remaining: 18s
# 500:	learn: 0.0139954	total: 8.88s	remaining: 8.85s
# 999:	learn: 0.0048734	total: 17.7s	remaining: 0us
# 0:	learn: 0.6547349	total: 17.7ms	remaining: 17.7s
# 500:	learn: 0.0140880	total: 8.88s	remaining: 8.84s
# 999:	learn: 0.0052230	total: 17.7s	remaining: 0us
# 0:	learn: 0.6184860	total: 18.6ms	remaining: 18.6s
# 500:	learn: 0.0052057	total: 8.88s	remaining: 8.84s
# 999:	learn: 0.0031637	total: 17.6s	remaining: 0us
# 0:	learn: 0.6187070	total: 18ms	remaining: 17.9s
# 500:	learn: 0.0050458	total: 8.93s	remaining: 8.9s
# 999:	learn: 0.0028647	total: 17.6s	remaining: 0us
# 0:	learn: 0.6186047	total: 17.7ms	remaining: 17.7s
# 500:	learn: 0.0050427	total: 8.86s	remaining: 8.82s
# 999:	learn: 0.0030999	total: 17.5s	remaining: 0us
# 0:	learn: 0.6561793	total: 19.7ms	remaining: 19.6s
# 500:	learn: 0.0166825	total: 8.86s	remaining: 8.82s
# 999:	learn: 0.0064832	total: 17.7s	remaining: 0us
# 0:	learn: 0.6559918	total: 17ms	remaining: 17s
# 500:	learn: 0.0163953	total: 8.86s	remaining: 8.83s
# 999:	learn: 0.0060895	total: 17.7s	remaining: 0us
# 0:	learn: 0.6562358	total: 18.2ms	remaining: 18.1s
# 500:	learn: 0.0163980	total: 8.86s	remaining: 8.83s
# 999:	learn: 0.0062497	total: 17.7s	remaining: 0us
# 0:	learn: 0.6213702	total: 17.5ms	remaining: 17.5s
# 500:	learn: 0.0062090	total: 8.86s	remaining: 8.83s
# 999:	learn: 0.0035744	total: 17.5s	remaining: 0us
# 0:	learn: 0.6210634	total: 18.1ms	remaining: 18.1s
# 500:	learn: 0.0059575	total: 8.89s	remaining: 8.85s
# 999:	learn: 0.0030521	total: 17.7s	remaining: 0us
# 0:	learn: 0.6214222	total: 19.3ms	remaining: 19.2s
# 500:	learn: 0.0062462	total: 8.84s	remaining: 8.8s
# 999:	learn: 0.0033033	total: 17.5s	remaining: 0us
# 0:	learn: 0.6582245	total: 6.3ms	remaining: 6.29s
# 500:	learn: 0.0098619	total: 3.1s	remaining: 3.09s
# 999:	learn: 0.0028493	total: 6.23s	remaining: 0us
# 0:	learn: 0.6580907	total: 6.42ms	remaining: 6.42s
# 500:	learn: 0.0092354	total: 3.16s	remaining: 3.15s
# 999:	learn: 0.0027311	total: 6.28s	remaining: 0us
# 0:	learn: 0.6626650	total: 6.21ms	remaining: 6.2s
# 500:	learn: 0.0084132	total: 3.17s	remaining: 3.15s
# 999:	learn: 0.0026961	total: 6.3s	remaining: 0us
# 0:	learn: 0.6250778	total: 6.47ms	remaining: 6.46s
# 500:	learn: 0.0028130	total: 3.13s	remaining: 3.11s
# 999:	learn: 0.0023889	total: 6.12s	remaining: 0us
# 0:	learn: 0.6249016	total: 6.38ms	remaining: 6.38s
# 500:	learn: 0.0025303	total: 3.15s	remaining: 3.14s
# 999:	learn: 0.0022826	total: 6.04s	remaining: 0us
# 0:	learn: 0.6336332	total: 5.9ms	remaining: 5.9s
# 500:	learn: 0.0025561	total: 3.16s	remaining: 3.15s
# 999:	learn: 0.0021210	total: 6.17s	remaining: 0us
# 0:	learn: 0.6583828	total: 6.29ms	remaining: 6.29s
# 500:	learn: 0.0115350	total: 3.16s	remaining: 3.15s
# 999:	learn: 0.0036452	total: 6.32s	remaining: 0us
# 0:	learn: 0.6597141	total: 6ms	remaining: 5.99s
# 500:	learn: 0.0108773	total: 3.15s	remaining: 3.14s
# 999:	learn: 0.0033411	total: 6.22s	remaining: 0us
# 0:	learn: 0.6630145	total: 6.81ms	remaining: 6.8s
# 500:	learn: 0.0105784	total: 3.17s	remaining: 3.15s
# 999:	learn: 0.0032310	total: 6.36s	remaining: 0us
# 0:	learn: 0.6253721	total: 6.67ms	remaining: 6.66s
# 500:	learn: 0.0034962	total: 3.11s	remaining: 3.1s
# 999:	learn: 0.0027413	total: 5.97s	remaining: 0us
# 0:	learn: 0.6279259	total: 6.57ms	remaining: 6.57s
# 500:	learn: 0.0033420	total: 3.16s	remaining: 3.15s
# 999:	learn: 0.0028354	total: 5.99s	remaining: 0us
# 0:	learn: 0.6342936	total: 6.1ms	remaining: 6.09s
# 500:	learn: 0.0033243	total: 3.2s	remaining: 3.19s
# 999:	learn: 0.0025048	total: 6.23s	remaining: 0us
# 0:	learn: 0.6585102	total: 6.19ms	remaining: 6.18s
# 500:	learn: 0.0131508	total: 3.12s	remaining: 3.11s
# 999:	learn: 0.0042532	total: 6.26s	remaining: 0us
# 0:	learn: 0.6597551	total: 6.66ms	remaining: 6.65s
# 500:	learn: 0.0123556	total: 3.21s	remaining: 3.2s
# 999:	learn: 0.0040378	total: 6.3s	remaining: 0us
# 0:	learn: 0.6631080	total: 6.2ms	remaining: 6.2s
# 500:	learn: 0.0123335	total: 3.38s	remaining: 3.37s
# 999:	learn: 0.0038090	total: 7.08s	remaining: 0us
# 0:	learn: 0.6256113	total: 7.59ms	remaining: 7.58s
# 500:	learn: 0.0042575	total: 3.16s	remaining: 3.15s
# 999:	learn: 0.0031655	total: 6.25s	remaining: 0us
# 0:	learn: 0.6280015	total: 7.19ms	remaining: 7.18s
# 500:	learn: 0.0039398	total: 3.19s	remaining: 3.17s
# 999:	learn: 0.0029828	total: 6.14s	remaining: 0us
# 0:	learn: 0.6344705	total: 6ms	remaining: 6s
# 500:	learn: 0.0038740	total: 3.22s	remaining: 3.2s
# 999:	learn: 0.0028718	total: 6.32s	remaining: 0us
# 0:	learn: 0.6574961	total: 7.57ms	remaining: 7.56s
# 500:	learn: 0.0143251	total: 3.15s	remaining: 3.13s
# 999:	learn: 0.0047785	total: 6.34s	remaining: 0us
# 0:	learn: 0.6598005	total: 6.62ms	remaining: 6.61s
# 500:	learn: 0.0140170	total: 3.21s	remaining: 3.2s
# 999:	learn: 0.0047382	total: 6.32s	remaining: 0us
# 0:	learn: 0.6631806	total: 6.34ms	remaining: 6.34s
# 500:	learn: 0.0132308	total: 3.17s	remaining: 3.16s
# 999:	learn: 0.0044608	total: 6.38s	remaining: 0us
# 0:	learn: 0.6236871	total: 7.5ms	remaining: 7.49s
# 500:	learn: 0.0047940	total: 3.22s	remaining: 3.21s
# 999:	learn: 0.0034635	total: 6.3s	remaining: 0us
# 0:	learn: 0.6280886	total: 8.36ms	remaining: 8.35s
# 500:	learn: 0.0044735	total: 3.17s	remaining: 3.16s
# 999:	learn: 0.0030175	total: 6.25s	remaining: 0us
# 0:	learn: 0.6346100	total: 6.21ms	remaining: 6.2s
# 500:	learn: 0.0043496	total: 3.2s	remaining: 3.19s
# 999:	learn: 0.0029578	total: 6.3s	remaining: 0us
# 0:	learn: 0.6211277	total: 6.1ms	remaining: 6.09s
# C:\Users\sebgi\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 123 fits failed out of a total of 480.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sebgi\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sebgi\anaconda3\lib\site-packages\imblearn\pipeline.py", line 266, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params_last_step)
#   File "C:\Users\sebgi\anaconda3\lib\site-packages\catboost\core.py", line 5007, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\sebgi\anaconda3\lib\site-packages\catboost\core.py", line 2262, in _fit
#     train_params = self._prepare_train_params(
#   File "C:\Users\sebgi\anaconda3\lib\site-packages\catboost\core.py", line 2194, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 6032, in _catboost._check_train_params
#   File "_catboost.pyx", line 6051, in _catboost._check_train_params
# _catboost.CatBoostError: C:/Program Files (x86)/Go Agent/pipelines/BuildMaster/catboost.git/catboost/private/libs/options/catboost_options.cpp:747: Ordered boosting is not supported for nonsymmetric trees.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sebgi\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sebgi\anaconda3\lib\site-packages\imblearn\pipeline.py", line 266, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params_last_step)
#   File "C:\Users\sebgi\anaconda3\lib\site-packages\catboost\core.py", line 5007, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "C:\Users\sebgi\anaconda3\lib\site-packages\catboost\core.py", line 2278, in _fit
#     self._train(
#   File "C:\Users\sebgi\anaconda3\lib\site-packages\catboost\core.py", line 1705, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 4585, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 4634, in _catboost._CatBoost._train
# _catboost.CatBoostError: (The process cannot access the file because it is being used by another process.) C:/Program Files (x86)/Go Agent/pipelines/BuildMaster/catboost.git/util/system/file.cpp:857: can't open "catboost_info\\learn\\events.out.tfevents" with mode WrOnly|CreateAlways|Seq (0x00000034)
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\sebgi\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.96980826 0.97192464 0.97121884 0.97192416 0.96910271 0.97319421
#  0.9689617  0.97051364        nan        nan        nan        nan
#         nan        nan        nan        nan 0.96994891 0.97248853
#  0.9710779  0.97037216 0.97093659 0.97065471 0.97009033        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.97178327 0.97220647 0.97234765 0.97305285
#  0.9712189  0.97262978 0.9729119  0.97404065        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.97164191 0.97065435 0.97262984 0.9734764  0.9717831  0.97178298
#  0.97220658 0.9736168         nan        nan        nan        nan
#         nan        nan        nan        nan 0.97234753 0.97361734
#  0.97305303 0.97404053 0.97389941 0.97262972 0.97234747 0.97361734
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.97220623 0.97192416 0.97220629 0.97418171
#         nan 0.97277096 0.97150097        nan 0.97065477 0.97023128
#  0.97107802 0.97079565 0.97051346 0.97135996 0.96980844 0.97065459
#  0.97262972 0.97347628 0.97291196 0.97375828 0.97262978 0.97361704
#  0.97136002 0.97319397 0.96966726 0.9702314  0.97051358 0.96924353
#  0.97023134 0.9720654  0.97136002 0.97009027 0.97277054 0.9736174
#  0.97220635 0.97277066 0.97262942 0.97234741 0.97164197 0.9727709
#  0.97079577 0.96994909 0.96994921 0.97023116 0.97009033 0.97079553
#  0.96980815 0.97037246 0.97333497 0.97164197 0.97277078 0.97136008
#  0.97262954 0.9719241  0.97220605 0.97206546 0.96966708 0.97136014
#  0.97051358 0.97107784 0.96994915 0.9702311  0.97023146 0.97093683
#  0.97150097 0.97234753 0.97164227 0.97291196 0.9710776  0.97135979
#  0.97164215 0.97136002 0.97051364 0.97079559 0.97023116 0.96938472
#  0.97037246 0.9705134  0.97023128 0.97051352]
#   warnings.warn(
# 500:	learn: 0.0206595	total: 2.96s	remaining: 2.95s
# 999:	learn: 0.0083660	total: 5.69s	remaining: 0us
# {'cat__boosting_type': 'Plain', 'cat__depth': 6, 'cat__grow_policy': 'SymmetricTree', 'cat__l2_leaf_reg': 5, 'cat__learning_rate': 0.06}

# %% [markdown]
# GridSearchCV has found the best parameters, detailed above. I'll use those parameters to build the final model.

# %%
# Instantiate Model

cb = CatBoostClassifier(depth=6,
                        learning_rate=0.06,
                        l2_leaf_reg=5,
                        iterations=1000,
                        boosting_type='Plain',
                        verbose=False,
                        grow_policy='SymmetricTree'
                           )

# Pipeline

pipe = Pipeline(steps=[("scaler", StandardScaler()), ('ros', ros), ("cat", cb)])

# Fit Model

pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('ros', RandomOverSampler(random_state=0)),
#                 ('cat',
#                  <catboost.core.CatBoostClassifier object at 0x000001DD189C8100>)])

# %%
# Train Predictions
y_train_pred = pipe.predict(X_train)
y_train_prob = pipe.predict_proba(X_train)

# Display Train Results
show_summary_report(y_train, y_train_pred, y_train_prob)
# Out:
# Accuracy : 0.9999 [TP / N] Proportion of predicted labels that match the true labels. Best: 1, Worst: 0
# Precision: 0.9991 [TP / (TP + FP)] Not to label a negative sample as positive.        Best: 1, Worst: 0
# Recall   : 1.0000 [TP / (TP + FN)] Find all the positive samples.                     Best: 1, Worst: 0
# ROC AUC  : 1.0000                                                                     Best: 1, Worst: < 0.5
# F1 Score : 0.9996
# -----------------------------------------------------------------------------------------------------------
# TP: True Positives, FP: False Positives, TN: True Negatives, FN: False Negatives, N: Number of samples

# %%
# Test Predictions
y_test_pred = pipe.predict(X_test)
y_test_prob = pipe.predict_proba(X_test)

# Display Test Results
show_summary_report(y_test, y_test_pred, y_test_prob)
# Out:
# Accuracy : 0.9753 [TP / N] Proportion of predicted labels that match the true labels. Best: 1, Worst: 0
# Precision: 0.9293 [TP / (TP + FP)] Not to label a negative sample as positive.        Best: 1, Worst: 0
# Recall   : 0.9160 [TP / (TP + FN)] Find all the positive samples.                     Best: 1, Worst: 0
# ROC AUC  : 0.9946                                                                     Best: 1, Worst: < 0.5
# F1 Score : 0.9226
# -----------------------------------------------------------------------------------------------------------
# TP: True Positives, FP: False Positives, TN: True Negatives, FN: False Negatives, N: Number of samples

# %% [markdown]
# The final model is scoring very well, recall is 0.9160 which is the metric that will be of most use to the business, as they don't want to miss reaching out to customers that are likely to churn.

# %% [markdown]
# ### Feature Importance <a id='feature_importance'></a>

# %%
# Create Feature Importance DataFrame
feat_imp = pd.DataFrame(pipe[2].feature_importances_, index=X.columns, columns=["Importance"])

# Sort Values
feat_imp = feat_imp.sort_values(by="Importance", ascending=False)

# Instantiate Figure & Axes
fig, ax = plt.subplots(figsize=(10,8))

# Plot Barplot
sns.barplot(data=feat_imp, y=feat_imp.index, x='Importance', palette='BuPu_r')

# Formatting
ax.set_title('Feature Importance', fontsize=16, fontweight='bold')
ax.set_xlabel('%')
ax.set_ylabel('Feature')
sns.despine(fig=fig, bottom=True)

# %% [markdown]
# The importance of features above is in line with the initial insights I discovered. The ability to predict whether a customer will churn or not, is related primarily to the amount of transaction activity they're making. The less activity a customer is making, the more likely they are to churn.
#
# This makes sense, as customers that aren't satisfied with their current offering will be seeking alternatives and may take some time in winding up their accounts.

# %% [markdown]
# ## Conclusion <a id='conclusion'></a>

# %% [markdown]
# I've been able to successfully train a model to predict whether a customer will churn or not with % Recall. This is a well performing model that can have significant value in a business sense. Successful implementation of this model will allow the relevant business stakeholders to use this information and apply strategies to these customers, with the aim of reducing their chance of churning.
#
# Further development of this work can be done with:
# - PCA
# - Imputing 'Unknown' values
# - Acquiring more Data
# - Further fine tuning to increase Recall at expense of Precision
# - Implementing automated system to work with this model in implementing the strategy to keep customers
